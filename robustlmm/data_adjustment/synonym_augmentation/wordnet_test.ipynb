# %%
# from head import *

from nltk.corpus import wordnet

synonyms = []

for syn in wordnet.synsets("Soil"):
    for lm in syn.lemmas():
             synonyms.append(lm.name())
# print(set(synonyms))
print(list(set(synonyms)))
# Out:
# ['ground', 'territory', 'bemire', 'soil', 'grime', 'filth', 'land', 'stain', 'grunge', 'dirty', 'begrime', 'grease', 'dirt', 'colly']
