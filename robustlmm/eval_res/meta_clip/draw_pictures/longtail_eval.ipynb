# %%
lt_results = [{"ratio": 0.8,
  "result": [{"name": "baseline",
    "head_acc": 0.8015506113781177,
    "tail_acc": 0.7367987389231023},
   {"name": "balance",
    "head_acc": 0.805062168794039,
    "tail_acc": 0.7383128834357086},
   {"name": "aug",
    "head_acc": 0.8051054704415656,
    "tail_acc": 0.7391206543968554}],
  "all_pass_cnt": 117360},
 {"ratio": 0.81,
  "result": [{"name": "baseline",
    "head_acc": 0.7990473293827774,
    "tail_acc": 0.7362287645647412},
   {"name": "balance",
    "head_acc": 0.80267257956919,
    "tail_acc": 0.7375522547364005},
   {"name": "aug",
    "head_acc": 0.8026343157647879,
    "tail_acc": 0.7384674908833381}],
  "all_pass_cnt": 112430},
 {"ratio": 0.8200000000000001,
  "result": [{"name": "baseline",
    "head_acc": 0.7970727708060721,
    "tail_acc": 0.7350318173749277},
   {"name": "balance",
    "head_acc": 0.8006092959558327,
    "tail_acc": 0.7363278731417652},
   {"name": "aug",
    "head_acc": 0.8005934579875664,
    "tail_acc": 0.7372688451368704}],
  "all_pass_cnt": 107017},
 {"ratio": 0.8300000000000001,
  "result": [{"name": "baseline",
    "head_acc": 0.7947617318610016,
    "tail_acc": 0.7341903682162038},
   {"name": "balance",
    "head_acc": 0.7981562004623876,
    "tail_acc": 0.73552126977878},
   {"name": "aug",
    "head_acc": 0.7981827681790702,
    "tail_acc": 0.7364676886677248}],
  "all_pass_cnt": 101435},
 {"ratio": 0.8400000000000001,
  "result": [{"name": "baseline",
    "head_acc": 0.7936666777211487,
    "tail_acc": 0.7306257867674641},
   {"name": "balance",
    "head_acc": 0.7968121973868628,
    "tail_acc": 0.7321075764365408},
   {"name": "aug",
    "head_acc": 0.7970368773629861,
    "tail_acc": 0.7328746079499082}],
  "all_pass_cnt": 93738},
 {"ratio": 0.8500000000000001,
  "result": [{"name": "baseline",
    "head_acc": 0.7915123590719895,
    "tail_acc": 0.7293293761772395},
   {"name": "balance",
    "head_acc": 0.794663468745436,
    "tail_acc": 0.7306866046459322},
   {"name": "aug",
    "head_acc": 0.7949325043985775,
    "tail_acc": 0.7314274299412928}],
  "all_pass_cnt": 87605},
 {"ratio": 0.8600000000000001,
  "result": [{"name": "baseline",
    "head_acc": 0.784555685483099,
    "tail_acc": 0.735157508334337},
   {"name": "balance",
    "head_acc": 0.7875252303316417,
    "tail_acc": 0.7366508097040277},
   {"name": "aug",
    "head_acc": 0.7879244467948515,
    "tail_acc": 0.7372176649062361}],
  "all_pass_cnt": 80091},
 {"ratio": 0.8700000000000001,
  "result": [{"name": "baseline",
    "head_acc": 0.783835385465655,
    "tail_acc": 0.7318961748634418},
   {"name": "balance",
    "head_acc": 0.7866514586906435,
    "tail_acc": 0.733546448087485},
   {"name": "aug",
    "head_acc": 0.7869560905112072,
    "tail_acc": 0.7343114754098898}],
  "all_pass_cnt": 73200},
 {"ratio": 0.8800000000000001,
  "result": [{"name": "baseline",
    "head_acc": 0.783667081343695,
    "tail_acc": 0.7255876002467964},
   {"name": "balance",
    "head_acc": 0.7865290206938557,
    "tail_acc": 0.7269818013572201},
   {"name": "aug",
    "head_acc": 0.786901561057969,
    "tail_acc": 0.72764959901299}],
  "all_pass_cnt": 64840},
 {"ratio": 0.8900000000000001,
  "result": [{"name": "baseline",
    "head_acc": 0.7818564992944349,
    "tail_acc": 0.7247909310537254},
   {"name": "balance",
    "head_acc": 0.784799211152287,
    "tail_acc": 0.7258333192546339},
   {"name": "aug",
    "head_acc": 0.7850228469417471,
    "tail_acc": 0.7269196330523406}],
  "all_pass_cnt": 59191},
 {"ratio": 0.9000000000000001,
  "result": [{"name": "baseline",
    "head_acc": 0.7854501289511454,
    "tail_acc": 0.698349571644506},
   {"name": "balance",
    "head_acc": 0.7882480657351655,
    "tail_acc": 0.6994372585250724},
   {"name": "aug",
    "head_acc": 0.788420200324021,
    "tail_acc": 0.7009134050058379}],
  "all_pass_cnt": 47624},
 {"ratio": 0.9100000000000001,
  "result": [{"name": "baseline",
    "head_acc": 0.7838016290221294,
    "tail_acc": 0.691795170206532},
   {"name": "balance",
    "head_acc": 0.7862925307609077,
    "tail_acc": 0.6939069925322062},
   {"name": "aug",
    "head_acc": 0.7866368205188629,
    "tail_acc": 0.6948622829986972}],
  "all_pass_cnt": 41244},
 {"ratio": 0.9200000000000002,
  "result": [{"name": "baseline",
    "head_acc": 0.777651236089586,
    "tail_acc": 0.7044405025868045},
   {"name": "balance",
    "head_acc": 0.7801494496729963,
    "tail_acc": 0.7064301552106063},
   {"name": "aug",
    "head_acc": 0.78045632557659,
    "tail_acc": 0.7077191426459334}],
  "all_pass_cnt": 33825},
 {"ratio": 0.9300000000000002,
  "result": [{"name": "baseline",
    "head_acc": 0.7759158532915532,
    "tail_acc": 0.7015513463848684},
   {"name": "balance",
    "head_acc": 0.7783651158791596,
    "tail_acc": 0.7037635168562826},
   {"name": "aug",
    "head_acc": 0.778717697897475,
    "tail_acc": 0.7049438122835191}],
  "all_pass_cnt": 28298},
 {"ratio": 0.9400000000000002,
  "result": [{"name": "baseline",
    "head_acc": 0.7752916071022069,
    "tail_acc": 0.6827163393779754},
   {"name": "balance",
    "head_acc": 0.7778906913626707,
    "tail_acc": 0.6834914967584127},
   {"name": "aug",
    "head_acc": 0.7780807798289091,
    "tail_acc": 0.6864183031100061}],
  "all_pass_cnt": 21286},
 {"ratio": 0.9500000000000002,
  "result": [{"name": "baseline",
    "head_acc": 0.7721507357555836,
    "tail_acc": 0.6866389822687983},
   {"name": "balance",
    "head_acc": 0.7746439204149146,
    "tail_acc": 0.6880693428251216},
   {"name": "aug",
    "head_acc": 0.7749054889222656,
    "tail_acc": 0.6911607672533072}],
  "all_pass_cnt": 15171},
 {"ratio": 0.9600000000000002,
  "result": [{"name": "baseline",
    "head_acc": 0.7694799584510404,
    "tail_acc": 0.6824891982717338},
   {"name": "balance",
    "head_acc": 0.7719015444952468,
    "tail_acc": 0.6848175708113391},
   {"name": "aug",
    "head_acc": 0.7723417887410061,
    "tail_acc": 0.6858137301968413}],
  "all_pass_cnt": 8332},
 {"ratio": 0.9700000000000002,
  "result": [{"name": "baseline",
    "head_acc": 0.7680722317514641,
    "tail_acc": 0.6735136343316978},
   {"name": "balance",
    "head_acc": 0.7705617495711676,
    "tail_acc": 0.6725748770675044},
   {"name": "aug",
    "head_acc": 0.771017247951195,
    "tail_acc": 0.6733348234242321}],
  "all_pass_cnt": 4474},
 {"ratio": 0.9800000000000002,
  "result": [{"name": "baseline",
    "head_acc": 0.7666836369121496,
    "tail_acc": 0.710144274120827},
   {"name": "balance",
    "head_acc": 0.7691669495040692,
    "tail_acc": 0.7063119927862921},
   {"name": "aug",
    "head_acc": 0.7696095900742693,
    "tail_acc": 0.7086113615870134}],
  "all_pass_cnt": 2218},
 {"ratio": 0.9900000000000002,
  "result": [{"name": "baseline",
    "head_acc": 0.7659710180246657,
    "tail_acc": 0.793877551020407},
   {"name": "balance",
    "head_acc": 0.7683949309662588,
    "tail_acc": 0.7949999999999989},
   {"name": "aug",
    "head_acc": 0.7688214121682789,
    "tail_acc": 0.8031632653061216}],
  "all_pass_cnt": 980}]

# %%
lt_results_bak = lt_results
lt_results = lt_results_bak[:-2]

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import FancyArrowPatch
import matplotlib.patches as patches
import numpy as np

baseline_overall=76.6
balanced_overall=76.9
aug_overall=77.0

baseline_data = [baseline_overall]+[item["result"][0]["tail_acc"]*100 for item in lt_results]
balanced_data = [balanced_overall]+[item["result"][1]["tail_acc"]*100 for item in lt_results]
aug_data = [aug_overall]+[item["result"][2]["tail_acc"]*100 for item in lt_results] 
ratio_data = [21]+[(1-item["ratio"])*100 for item in lt_results] 

# 生成示例数据
x = ratio_data
y1 = baseline_data
y2 = balanced_data
y3 = aug_data

# 创建图形和轴对象
fig, ax = plt.subplots(figsize=(15, 5))  # 细长的图形尺寸

# 绘制折线图 
ax.plot(x, y1, label='LLaVA 1.5', color='#FF5733')  # 选择一种明亮的橘色
ax.plot(x, y2, label='balanced data', color='#33C4FF')  # 选择一种明亮的蓝色
ax.plot(x, y3, label='Ours', color='#8A2BE2')  # 选择一种明亮的绿色

# 设置标题和轴标签
# ax.set_title('Sine and Cosine Waves', fontsize=14, fontweight='bold')
ax.set_xlabel('Tail Data @ x (%)', fontsize=12)
ax.set_ylabel('Accuracy(%)', fontsize=12)
xtick_labels = [int(i) for i in x]  # 创建刻度标签，例如t0, t1, ..., t10
xtick_labels[0] = "Overall"
ax.set_xticks(x)  # 设置刻度位置
ax.set_xticklabels(xtick_labels)  # 设置刻度的标签
ax.set_xlim(left=np.min(x) - 1, right=np.max(x) + 1)
# 添加图例
ax.legend()
ax.grid(True, color='gray', linestyle='--', linewidth=0.5)
ax.scatter(
    [21], [77],  # 五角星的位置
    marker=(5, 1),  # marker参数设置为五角星，5表示星形，1是星形的样式
    s=250,  # size
    color='gold', edgecolor='black',
    alpha=1, 
    zorder = 10
)
ax.scatter(
    [21], [76.6],  # 五角星的位置
    marker='o',  # marker参数设置为五角星，5表示星形，1是星形的样式
    s=25,  # size
    color='red', edgecolor='red',
    alpha=1, 
    zorder = 10
)

# 将五角星添加到图表中
# ax.add_patch(star)
# 设置网格

# %% [markdown]
# ### 2.SQA-IMG LT EVAL

# %%
lt_results=[{"ratio": 0.8,
  "result": [{"name": "baseline",
    "head_acc": 0.7459677419354839,
    "tail_acc": 0.6851328434143584},
   {"name": "balance",
    "head_acc": 0.7620967741935484,
    "tail_acc": 0.6851328434143584},
   {"name": "aug",
    "head_acc": 0.7862903225806451,
    "tail_acc": 0.6902204635387225}],
  "all_pass_cnt": 1769},
 {"ratio": 0.81,
  "result": [{"name": "baseline",
    "head_acc": 0.761744966442953,
    "tail_acc": 0.680628272251309},
   {"name": "balance",
    "head_acc": 0.785234899328859,
    "tail_acc": 0.6788830715532286},
   {"name": "aug",
    "head_acc": 0.7986577181208053,
    "tail_acc": 0.685282140779523}],
  "all_pass_cnt": 1719},
 {"ratio": 0.8200000000000001,
  "result": [{"name": "baseline",
    "head_acc": 0.7734138972809668,
    "tail_acc": 0.6767497034400949},
   {"name": "balance",
    "head_acc": 0.7945619335347432,
    "tail_acc": 0.67497034400949},
   {"name": "aug",
    "head_acc": 0.8096676737160121,
    "tail_acc": 0.6809015421115066}],
  "all_pass_cnt": 1686},
 {"ratio": 0.8300000000000001,
  "result": [{"name": "baseline",
    "head_acc": 0.7692307692307693,
    "tail_acc": 0.6734820322180917},
   {"name": "balance",
    "head_acc": 0.7915632754342432,
    "tail_acc": 0.6703841387856257},
   {"name": "aug",
    "head_acc": 0.8014888337468983,
    "tail_acc": 0.6771995043370508}],
  "all_pass_cnt": 1614},
 {"ratio": 0.8400000000000001,
  "result": [{"name": "baseline",
    "head_acc": 0.7405857740585774,
    "tail_acc": 0.6777128005198181},
   {"name": "balance",
    "head_acc": 0.7489539748953975,
    "tail_acc": 0.6777128005198181},
   {"name": "aug",
    "head_acc": 0.7656903765690377,
    "tail_acc": 0.682261208576998}],
  "all_pass_cnt": 1539},
 {"ratio": 0.8500000000000001,
  "result": [{"name": "baseline",
    "head_acc": 0.726775956284153,
    "tail_acc": 0.6798365122615804},
   {"name": "balance",
    "head_acc": 0.7395264116575592,
    "tail_acc": 0.6777929155313351},
   {"name": "aug",
    "head_acc": 0.7540983606557377,
    "tail_acc": 0.6825613079019074}],
  "all_pass_cnt": 1468},
 {"ratio": 0.8600000000000001,
  "result": [{"name": "baseline",
    "head_acc": 0.7201986754966887,
    "tail_acc": 0.6808209483368719},
   {"name": "balance",
    "head_acc": 0.7317880794701986,
    "tail_acc": 0.6786978060863411},
   {"name": "aug",
    "head_acc": 0.7450331125827815,
    "tail_acc": 0.6836518046709129}],
  "all_pass_cnt": 1413},
 {"ratio": 0.8700000000000001,
  "result": [{"name": "baseline",
    "head_acc": 0.6853448275862069,
    "tail_acc": 0.6964420893262679},
   {"name": "balance",
    "head_acc": 0.6882183908045977,
    "tail_acc": 0.6979560938682816},
   {"name": "aug",
    "head_acc": 0.7054597701149425,
    "tail_acc": 0.700227100681302}],
  "all_pass_cnt": 1321},
 {"ratio": 0.8800000000000001,
  "result": [{"name": "baseline",
    "head_acc": 0.6808785529715762,
    "tail_acc": 0.6999195494770716},
   {"name": "balance",
    "head_acc": 0.6886304909560723,
    "tail_acc": 0.6983105390185036},
   {"name": "aug",
    "head_acc": 0.7067183462532299,
    "tail_acc": 0.6991150442477876}],
  "all_pass_cnt": 1243},
 {"ratio": 0.8900000000000001,
  "result": [{"name": "baseline",
    "head_acc": 0.6751740139211136,
    "tail_acc": 0.7056277056277056},
   {"name": "balance",
    "head_acc": 0.679814385150812,
    "tail_acc": 0.7056277056277056},
   {"name": "aug",
    "head_acc": 0.6960556844547564,
    "tail_acc": 0.7064935064935065}],
  "all_pass_cnt": 1155},
 {"ratio": 0.9000000000000001,
  "result": [{"name": "baseline",
    "head_acc": 0.6850551654964895,
    "tail_acc": 0.7},
   {"name": "balance",
    "head_acc": 0.6920762286860582,
    "tail_acc": 0.6970588235294117},
   {"name": "aug",
    "head_acc": 0.6990972918756269,
    "tail_acc": 0.7049019607843138}],
  "all_pass_cnt": 1020},
 {"ratio": 0.9100000000000001,
  "result": [{"name": "baseline",
    "head_acc": 0.6692640692640692,
    "tail_acc": 0.7238979118329466},
   {"name": "balance",
    "head_acc": 0.6796536796536796,
    "tail_acc": 0.7146171693735499},
   {"name": "aug",
    "head_acc": 0.683982683982684,
    "tail_acc": 0.7262180974477959}],
  "all_pass_cnt": 862},
 {"ratio": 0.9200000000000002,
  "result": [{"name": "baseline",
    "head_acc": 0.6755695208169678,
    "tail_acc": 0.7217741935483871},
   {"name": "balance",
    "head_acc": 0.6857816182246661,
    "tail_acc": 0.7096774193548387},
   {"name": "aug",
    "head_acc": 0.6897093479968578,
    "tail_acc": 0.7231182795698925}],
  "all_pass_cnt": 744},
 {"ratio": 0.9300000000000002,
  "result": [{"name": "baseline",
    "head_acc": 0.692524682651622,
    "tail_acc": 0.6928213689482471},
   {"name": "balance",
    "head_acc": 0.7009873060648801,
    "tail_acc": 0.679465776293823},
   {"name": "aug",
    "head_acc": 0.7031029619181947,
    "tail_acc": 0.6994991652754591}],
  "all_pass_cnt": 599},
 {"ratio": 0.9400000000000002,
  "result": [{"name": "baseline",
    "head_acc": 0.6861575178997613,
    "tail_acc": 0.7243401759530792},
   {"name": "balance",
    "head_acc": 0.6867541766109785,
    "tail_acc": 0.7331378299120235},
   {"name": "aug",
    "head_acc": 0.6939140811455847,
    "tail_acc": 0.7419354838709677}],
  "all_pass_cnt": 341},
 {"ratio": 0.9500000000000002,
  "result": [{"name": "baseline",
    "head_acc": 0.693756727664155,
    "tail_acc": 0.6792452830188679},
   {"name": "balance",
    "head_acc": 0.6948331539289558,
    "tail_acc": 0.6918238993710691},
   {"name": "aug",
    "head_acc": 0.701291711517761,
    "tail_acc": 0.710691823899371}],
  "all_pass_cnt": 159},
 {"ratio": 0.9600000000000002,
  "result": [{"name": "baseline",
    "head_acc": 0.6946484784889821,
    "tail_acc": 0.6576576576576577},
   {"name": "balance",
    "head_acc": 0.6962224554039874,
    "tail_acc": 0.6666666666666666},
   {"name": "aug",
    "head_acc": 0.7030430220356768,
    "tail_acc": 0.6846846846846847}],
  "all_pass_cnt": 111},
 {"ratio": 0.9700000000000002,
  "result": [{"name": "baseline",
    "head_acc": 0.6917948717948718,
    "tail_acc": 0.7164179104477612},
   {"name": "balance",
    "head_acc": 0.6938461538461539,
    "tail_acc": 0.7164179104477612},
   {"name": "aug",
    "head_acc": 0.7015384615384616,
    "tail_acc": 0.7164179104477612}],
  "all_pass_cnt": 67},
 {"ratio": 0.9800000000000002,
  "result": [{"name": "baseline",
    "head_acc": 0.6940938919737506,
    "tail_acc": 0.6111111111111112},
   {"name": "balance",
    "head_acc": 0.696113074204947,
    "tail_acc": 0.6111111111111112},
   {"name": "aug",
    "head_acc": 0.7031802120141343,
    "tail_acc": 0.6388888888888888}],
  "all_pass_cnt": 36},
 {"ratio": 0.9900000000000002,
  "result": [{"name": "baseline",
    "head_acc": 0.6942065491183879,
    "tail_acc": 0.59375},
   {"name": "balance", "head_acc": 0.6962216624685138, "tail_acc": 0.59375},
   {"name": "aug", "head_acc": 0.7037783375314861, "tail_acc": 0.59375}],
  "all_pass_cnt": 32}]

# %%
lt_results_bak = lt_results

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import FancyArrowPatch
import matplotlib.patches as patches
import numpy as np

lt_results = lt_results_bak[:-3]
# baseline_overall=76.6
# balanced_overall=76.9
# aug_overall=77.0

baseline_data = [item["result"][0]["tail_acc"]*100 for item in lt_results]
balanced_data = [item["result"][1]["tail_acc"]*100 for item in lt_results]
aug_data = [item["result"][2]["tail_acc"]*100 for item in lt_results] 
ratio_data = [(1-item["ratio"])*100 for item in lt_results] 

# 生成示例数据
x = ratio_data
y1 = baseline_data
y2 = balanced_data
y3 = aug_data

# 创建图形和轴对象
fig, ax = plt.subplots(figsize=(15, 5))  # 细长的图形尺寸

# 绘制折线图 
ax.plot(x, y1, label='LLaVA 1.5', color='#FF5733')  # 选择一种明亮的橘色
ax.plot(x, y2, label='balanced data', color='#33C4FF')  # 选择一种明亮的蓝色
ax.plot(x, y3, label='Ours', color='#8A2BE2')  # 选择一种明亮的绿色

# 设置标题和轴标签
# ax.set_title('Sine and Cosine Waves', fontsize=14, fontweight='bold')
ax.set_xlabel('Tail Data @ x (%)', fontsize=12)
ax.set_ylabel('Accuracy(%)', fontsize=12)
xtick_labels = [int(i) for i in x]  # 创建刻度标签，例如t0, t1, ..., t10
xtick_labels[0] = "Overall"
ax.set_xticks(x)  # 设置刻度位置
ax.set_xticklabels(xtick_labels)  # 设置刻度的标签
ax.set_xlim(left=np.min(x) - 1, right=np.max(x) + 1)
# 添加图例
ax.legend()
ax.grid(True, color='gray', linestyle='--', linewidth=0.5)
star = patches.RegularPolygon(
    (21, 77),     # 中心点坐标
    numVertices=5,  # 顶点数量
    radius=0.2,   # 半径
    orientation=np.pi / 2,  # 方向，π/2弧度使得一个顶点向上
    color='gold', edgecolor='black'
)

# 将五角星添加到图表中
ax.add_patch(star)
# 设置网格
# Out:
# /tmp/ipykernel_113299/2407590498.py:42: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   star = patches.RegularPolygon(

# %% [markdown]
# ### 3. SQA FULL LT EVAL

# %%
lt_results=[{"ratio": 0.8,
  "result": [{"name": "baseline",
    "head_acc": 0.684981684981685,
    "tail_acc": 0.706359945872801},
   {"name": "balance",
    "head_acc": 0.7106227106227107,
    "tail_acc": 0.7147496617050068},
   {"name": "aug",
    "head_acc": 0.7252747252747253,
    "tail_acc": 0.7196211096075779}],
  "all_pass_cnt": 3695},
 {"ratio": 0.81,
  "result": [{"name": "baseline",
    "head_acc": 0.6959349593495935,
    "tail_acc": 0.7049089906232764},
   {"name": "balance",
    "head_acc": 0.7284552845528456,
    "tail_acc": 0.7118036403750689},
   {"name": "aug",
    "head_acc": 0.7398373983739838,
    "tail_acc": 0.7170435741864313}],
  "all_pass_cnt": 3626},
 {"ratio": 0.8200000000000001,
  "result": [{"name": "baseline",
    "head_acc": 0.7005730659025788,
    "tail_acc": 0.7042054755856618},
   {"name": "balance",
    "head_acc": 0.7335243553008596,
    "tail_acc": 0.7104149026248942},
   {"name": "aug",
    "head_acc": 0.7449856733524355,
    "tail_acc": 0.7154953429297206}],
  "all_pass_cnt": 3543},
 {"ratio": 0.8300000000000001,
  "result": [{"name": "baseline",
    "head_acc": 0.7134146341463414,
    "tail_acc": 0.7012569424144987},
   {"name": "balance",
    "head_acc": 0.7439024390243902,
    "tail_acc": 0.7071031862028646},
   {"name": "aug",
    "head_acc": 0.7524390243902439,
    "tail_acc": 0.7126571178018123}],
  "all_pass_cnt": 3421},
 {"ratio": 0.8400000000000001,
  "result": [{"name": "baseline",
    "head_acc": 0.7197125256673511,
    "tail_acc": 0.6988062442607897},
   {"name": "balance",
    "head_acc": 0.7392197125256673,
    "tail_acc": 0.706764615855525},
   {"name": "aug",
    "head_acc": 0.7535934291581109,
    "tail_acc": 0.7104377104377104}],
  "all_pass_cnt": 3267},
 {"ratio": 0.8500000000000001,
  "result": [{"name": "baseline",
    "head_acc": 0.7271171941830624,
    "tail_acc": 0.6946614583333334},
   {"name": "balance",
    "head_acc": 0.7467921300256629,
    "tail_acc": 0.7018229166666666},
   {"name": "aug",
    "head_acc": 0.7596236099230111,
    "tail_acc": 0.7054036458333334}],
  "all_pass_cnt": 3072},
 {"ratio": 0.8600000000000001,
  "result": [{"name": "baseline",
    "head_acc": 0.7243684992570579,
    "tail_acc": 0.6939550949913644},
   {"name": "balance",
    "head_acc": 0.7414561664190193,
    "tail_acc": 0.7015544041450777},
   {"name": "aug",
    "head_acc": 0.7540861812778603,
    "tail_acc": 0.7046632124352331}],
  "all_pass_cnt": 2895},
 {"ratio": 0.8700000000000001,
  "result": [{"name": "baseline",
    "head_acc": 0.714377406931964,
    "tail_acc": 0.6973537085352217},
   {"name": "balance",
    "head_acc": 0.7265725288831836,
    "tail_acc": 0.7070443533358182},
   {"name": "aug",
    "head_acc": 0.7400513478818999,
    "tail_acc": 0.7089079388743943}],
  "all_pass_cnt": 2683},
 {"ratio": 0.8800000000000001,
  "result": [{"name": "baseline",
    "head_acc": 0.7081447963800905,
    "tail_acc": 0.7003639304488476},
   {"name": "balance",
    "head_acc": 0.7222850678733032,
    "tail_acc": 0.708451273756571},
   {"name": "aug",
    "head_acc": 0.7341628959276018,
    "tail_acc": 0.7104731095835018}],
  "all_pass_cnt": 2473},
 {"ratio": 0.8900000000000001,
  "result": [{"name": "baseline",
    "head_acc": 0.6993496748374187,
    "tail_acc": 0.7074041034790366},
   {"name": "balance",
    "head_acc": 0.7158579289644822,
    "tail_acc": 0.7127564674397859},
   {"name": "aug",
    "head_acc": 0.7273636818409205,
    "tail_acc": 0.7140945584299733}],
  "all_pass_cnt": 2242},
 {"ratio": 0.9000000000000001,
  "result": [{"name": "baseline",
    "head_acc": 0.6999571367338191,
    "tail_acc": 0.7080712788259959},
   {"name": "balance",
    "head_acc": 0.7183883411915988,
    "tail_acc": 0.7091194968553459},
   {"name": "aug",
    "head_acc": 0.7243891984569224,
    "tail_acc": 0.7154088050314465}],
  "all_pass_cnt": 1908},
 {"ratio": 0.9100000000000001,
  "result": [{"name": "baseline",
    "head_acc": 0.6931034482758621,
    "tail_acc": 0.7204169221336604},
   {"name": "balance",
    "head_acc": 0.7118773946360153,
    "tail_acc": 0.7179644389944819},
   {"name": "aug",
    "head_acc": 0.7168582375478927,
    "tail_acc": 0.7259350091968118}],
  "all_pass_cnt": 1631},
 {"ratio": 0.9200000000000002,
  "result": [{"name": "baseline",
    "head_acc": 0.6963040446304045,
    "tail_acc": 0.7188638018936635},
   {"name": "balance",
    "head_acc": 0.7140864714086471,
    "tail_acc": 0.7144938091769847},
   {"name": "aug",
    "head_acc": 0.7179218967921897,
    "tail_acc": 0.7254187909686817}],
  "all_pass_cnt": 1373},
 {"ratio": 0.9300000000000002,
  "result": [{"name": "baseline",
    "head_acc": 0.7087929404349196,
    "tail_acc": 0.6882022471910112},
   {"name": "balance",
    "head_acc": 0.7261266939804601,
    "tail_acc": 0.6788389513108615},
   {"name": "aug",
    "head_acc": 0.7277024897573274,
    "tail_acc": 0.6985018726591761}],
  "all_pass_cnt": 1068},
 {"ratio": 0.9400000000000002,
  "result": [{"name": "baseline",
    "head_acc": 0.7047431939376929,
    "tail_acc": 0.6976401179941003},
   {"name": "balance",
    "head_acc": 0.7170923379174853,
    "tail_acc": 0.6991150442477876},
   {"name": "aug",
    "head_acc": 0.7218635980914959,
    "tail_acc": 0.7123893805309734}],
  "all_pass_cnt": 678},
 {"ratio": 0.9500000000000002,
  "result": [{"name": "baseline",
    "head_acc": 0.7094825321775676,
    "tail_acc": 0.652073732718894},
   {"name": "balance",
    "head_acc": 0.7207775151037562,
    "tail_acc": 0.6566820276497696},
   {"name": "aug",
    "head_acc": 0.7249802994483846,
    "tail_acc": 0.6797235023041475}],
  "all_pass_cnt": 434},
 {"ratio": 0.9600000000000002,
  "result": [{"name": "baseline",
    "head_acc": 0.7039586919104991,
    "tail_acc": 0.6954022988505747},
   {"name": "balance",
    "head_acc": 0.7147774772559626,
    "tail_acc": 0.7011494252873564},
   {"name": "aug",
    "head_acc": 0.7214162773543152,
    "tail_acc": 0.6954022988505747}],
  "all_pass_cnt": 174},
 {"ratio": 0.9700000000000002,
  "result": [{"name": "baseline",
    "head_acc": 0.7020348837209303,
    "tail_acc": 0.7610619469026548},
   {"name": "balance",
    "head_acc": 0.7126937984496124,
    "tail_acc": 0.7699115044247787},
   {"name": "aug",
    "head_acc": 0.720203488372093,
    "tail_acc": 0.7256637168141593}],
  "all_pass_cnt": 113},
 {"ratio": 0.9800000000000002,
  "result": [{"name": "baseline",
    "head_acc": 0.7026378896882494,
    "tail_acc": 0.7605633802816901},
   {"name": "balance",
    "head_acc": 0.7134292565947242,
    "tail_acc": 0.7605633802816901},
   {"name": "aug",
    "head_acc": 0.7203836930455636,
    "tail_acc": 0.7183098591549296}],
  "all_pass_cnt": 71},
 {"ratio": 0.9900000000000002,
  "result": [{"name": "baseline",
    "head_acc": 0.7030578117534639,
    "tail_acc": 0.7454545454545455},
   {"name": "balance",
    "head_acc": 0.7140468227424749,
    "tail_acc": 0.7272727272727273},
   {"name": "aug",
    "head_acc": 0.7209746774964166,
    "tail_acc": 0.6727272727272727}],
  "all_pass_cnt": 55}]

# %%
lt_results_bak = lt_results

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import FancyArrowPatch
import matplotlib.patches as patches
import numpy as np

lt_results = lt_results_bak[:-4]
# baseline_overall=76.6
# balanced_overall=76.9
# aug_overall=77.0

baseline_data = [item["result"][0]["tail_acc"]*100 for item in lt_results]
balanced_data = [item["result"][1]["tail_acc"]*100 for item in lt_results]
aug_data = [item["result"][2]["tail_acc"]*100 for item in lt_results] 
ratio_data = [(1-item["ratio"])*100 for item in lt_results] 

# 生成示例数据
x = ratio_data
y1 = baseline_data
y2 = balanced_data
y3 = aug_data

# 创建图形和轴对象
fig, ax = plt.subplots(figsize=(15, 5))  # 细长的图形尺寸

# 绘制折线图 
ax.plot(x, y1, label='LLaVA 1.5', color='#FF5733')  # 选择一种明亮的橘色
ax.plot(x, y2, label='balanced data', color='#33C4FF')  # 选择一种明亮的蓝色
ax.plot(x, y3, label='Ours', color='#8A2BE2')  # 选择一种明亮的绿色

# 设置标题和轴标签
# ax.set_title('Sine and Cosine Waves', fontsize=14, fontweight='bold')
ax.set_xlabel('Tail Data @ x (%)', fontsize=12)
ax.set_ylabel('Accuracy(%)', fontsize=12)
xtick_labels = [int(i) for i in x]  # 创建刻度标签，例如t0, t1, ..., t10
xtick_labels[0] = "Overall"
ax.set_xticks(x)  # 设置刻度位置
ax.set_xticklabels(xtick_labels)  # 设置刻度的标签
ax.set_xlim(left=np.min(x) - 1, right=np.max(x) + 1)
# 添加图例
ax.legend()
ax.grid(True, color='gray', linestyle='--', linewidth=0.5)
star = patches.RegularPolygon(
    (21, 77),     # 中心点坐标
    numVertices=5,  # 顶点数量
    radius=0.2,   # 半径
    orientation=np.pi / 2,  # 方向，π/2弧度使得一个顶点向上
    color='gold', edgecolor='black'
)

# 将五角星添加到图表中
ax.add_patch(star)
# 设置网格
# Out:
# /tmp/ipykernel_113299/1988522351.py:42: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   star = patches.RegularPolygon(
