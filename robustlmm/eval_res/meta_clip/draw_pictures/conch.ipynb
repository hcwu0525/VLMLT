# %%
lt_results = [{'ratio': 0.7,
  'result': [{'name': 'baseline',
    'head_acc': 0.821540641343529,
    'tail_acc': 0.7501042912703512},
   {'name': 'balance',
    'head_acc': 0.824782780822204,
    'tail_acc': 0.7522844897543697},
   {'name': 'aug',
    'head_acc': 0.8255683120455062,
    'tail_acc': 0.7526529655389599}],
  'all_pass_cnt': 166361},
 {'ratio': 0.71,
  'result': [{'name': 'baseline',
    'head_acc': 0.8198019219454884,
    'tail_acc': 0.749336451115461},
   {'name': 'balance',
    'head_acc': 0.8231574818591976,
    'tail_acc': 0.7514617663623933},
   {'name': 'aug',
    'head_acc': 0.8240086291429775,
    'tail_acc': 0.7518021106242874}],
  'all_pass_cnt': 163364},
 {'ratio': 0.72,
  'result': [{'name': 'baseline',
    'head_acc': 0.8165563402356674,
    'tail_acc': 0.7490085622749403},
   {'name': 'balance',
    'head_acc': 0.8196116755481163,
    'tail_acc': 0.7512106469484048},
   {'name': 'aug',
    'head_acc': 0.8207180130179224,
    'tail_acc': 0.7514542127517659}],
  'all_pass_cnt': 160121},
 {'ratio': 0.73,
  'result': [{'name': 'baseline',
    'head_acc': 0.8146284305726977,
    'tail_acc': 0.7482631246532626},
   {'name': 'balance',
    'head_acc': 0.8178988664572274,
    'tail_acc': 0.7503677901333027},
   {'name': 'aug',
    'head_acc': 0.8191226760636989,
    'tail_acc': 0.7505496117949618}],
  'all_pass_cnt': 156747},
 {'ratio': 0.74,
  'result': [{'name': 'baseline',
    'head_acc': 0.8128205951788615,
    'tail_acc': 0.7469698264810537},
   {'name': 'balance',
    'head_acc': 0.8164742158768247,
    'tail_acc': 0.7488818899710281},
   {'name': 'aug',
    'head_acc': 0.8176273146289732,
    'tail_acc': 0.7490607349742165}],
  'all_pass_cnt': 152087},
 {'ratio': 0.75,
  'result': [{'name': 'baseline',
    'head_acc': 0.8104450798689025,
    'tail_acc': 0.74602357055255},
   {'name': 'balance',
    'head_acc': 0.8141458448733193,
    'tail_acc': 0.747860826663746},
   {'name': 'aug',
    'head_acc': 0.814945281973788,
    'tail_acc': 0.74816985978315}],
  'all_pass_cnt': 147557},
 {'ratio': 0.76,
  'result': [{'name': 'baseline',
    'head_acc': 0.8067544042894504,
    'tail_acc': 0.7456194010482109},
   {'name': 'balance',
    'head_acc': 0.8103377202145253,
    'tail_acc': 0.7474503504059727},
   {'name': 'aug',
    'head_acc': 0.811188635888922,
    'tail_acc': 0.7477162238950883}],
  'all_pass_cnt': 142549},
 {'ratio': 0.77,
  'result': [{'name': 'baseline',
    'head_acc': 0.8043147608165171,
    'tail_acc': 0.7450484734482729},
   {'name': 'balance',
    'head_acc': 0.808157984606151,
    'tail_acc': 0.7466813775142512},
   {'name': 'aug',
    'head_acc': 0.8088541256206788,
    'tail_acc': 0.7470141802924314}],
  'all_pass_cnt': 138220},
 {'ratio': 0.78,
  'result': [{'name': 'baseline',
    'head_acc': 0.8019004929442038,
    'tail_acc': 0.7435791041601606},
   {'name': 'balance',
    'head_acc': 0.8061146820027779,
    'tail_acc': 0.744867235116337},
   {'name': 'aug',
    'head_acc': 0.8063273245699548,
    'tail_acc': 0.7454858419590111}],
  'all_pass_cnt': 131586},
 {'ratio': 0.79,
  'result': [{'name': 'baseline',
    'head_acc': 0.7993195965287734,
    'tail_acc': 0.7429455817857913},
   {'name': 'balance',
    'head_acc': 0.8033986096597642,
    'tail_acc': 0.7442058930636724},
   {'name': 'aug',
    'head_acc': 0.8035167431506106,
    'tail_acc': 0.7449072974557641}],
  'all_pass_cnt': 126318},
 {'ratio': 0.8,
  'result': [{'name': 'baseline',
    'head_acc': 0.8015506113781177,
    'tail_acc': 0.7367987389231023},
   {'name': 'balance',
    'head_acc': 0.805062168794039,
    'tail_acc': 0.7383128834357086},
   {'name': 'aug',
    'head_acc': 0.8051054704415656,
    'tail_acc': 0.7391206543968554}],
  'all_pass_cnt': 117360},
 {'ratio': 0.81,
  'result': [{'name': 'baseline',
    'head_acc': 0.7990473293827774,
    'tail_acc': 0.7362287645647412},
   {'name': 'balance',
    'head_acc': 0.80267257956919,
    'tail_acc': 0.7375522547364005},
   {'name': 'aug',
    'head_acc': 0.8026343157647879,
    'tail_acc': 0.7384674908833381}],
  'all_pass_cnt': 112430},
 {'ratio': 0.8200000000000001,
  'result': [{'name': 'baseline',
    'head_acc': 0.7970727708060721,
    'tail_acc': 0.7350318173749277},
   {'name': 'balance',
    'head_acc': 0.8006092959558327,
    'tail_acc': 0.7363278731417652},
   {'name': 'aug',
    'head_acc': 0.8005934579875664,
    'tail_acc': 0.7372688451368704}],
  'all_pass_cnt': 107017},
 {'ratio': 0.8300000000000001,
  'result': [{'name': 'baseline',
    'head_acc': 0.7947617318610016,
    'tail_acc': 0.7341903682162038},
   {'name': 'balance',
    'head_acc': 0.7981562004623876,
    'tail_acc': 0.73552126977878},
   {'name': 'aug',
    'head_acc': 0.7981827681790702,
    'tail_acc': 0.7364676886677248}],
  'all_pass_cnt': 101435},
 {'ratio': 0.8400000000000001,
  'result': [{'name': 'baseline',
    'head_acc': 0.7936666777211487,
    'tail_acc': 0.7306257867674641},
   {'name': 'balance',
    'head_acc': 0.7968121973868628,
    'tail_acc': 0.7321075764365408},
   {'name': 'aug',
    'head_acc': 0.7970368773629861,
    'tail_acc': 0.7328746079499082}],
  'all_pass_cnt': 93738},
 {'ratio': 0.8500000000000001,
  'result': [{'name': 'baseline',
    'head_acc': 0.7915123590719895,
    'tail_acc': 0.7293293761772395},
   {'name': 'balance',
    'head_acc': 0.794663468745436,
    'tail_acc': 0.7306866046459322},
   {'name': 'aug',
    'head_acc': 0.7949325043985775,
    'tail_acc': 0.7314274299412928}],
  'all_pass_cnt': 87605},
 {'ratio': 0.8600000000000001,
  'result': [{'name': 'baseline',
    'head_acc': 0.784555685483099,
    'tail_acc': 0.735157508334337},
   {'name': 'balance',
    'head_acc': 0.7875252303316417,
    'tail_acc': 0.7366508097040277},
   {'name': 'aug',
    'head_acc': 0.7879244467948515,
    'tail_acc': 0.7372176649062361}],
  'all_pass_cnt': 80091},
 {'ratio': 0.8700000000000001,
  'result': [{'name': 'baseline',
    'head_acc': 0.783835385465655,
    'tail_acc': 0.7318961748634418},
   {'name': 'balance',
    'head_acc': 0.7866514586906435,
    'tail_acc': 0.733546448087485},
   {'name': 'aug',
    'head_acc': 0.7869560905112072,
    'tail_acc': 0.7343114754098898}],
  'all_pass_cnt': 73200},
 {'ratio': 0.8800000000000001,
  'result': [{'name': 'baseline',
    'head_acc': 0.783667081343695,
    'tail_acc': 0.7255876002467964},
   {'name': 'balance',
    'head_acc': 0.7865290206938557,
    'tail_acc': 0.7269818013572201},
   {'name': 'aug',
    'head_acc': 0.786901561057969,
    'tail_acc': 0.72764959901299}],
  'all_pass_cnt': 64840},
 {'ratio': 0.8900000000000001,
  'result': [{'name': 'baseline',
    'head_acc': 0.7818564992944349,
    'tail_acc': 0.7247909310537254},
   {'name': 'balance',
    'head_acc': 0.784799211152287,
    'tail_acc': 0.7258333192546339},
   {'name': 'aug',
    'head_acc': 0.7850228469417471,
    'tail_acc': 0.7269196330523406}],
  'all_pass_cnt': 59191},
 {'ratio': 0.9000000000000001,
  'result': [{'name': 'baseline',
    'head_acc': 0.7854501289511454,
    'tail_acc': 0.698349571644506},
   {'name': 'balance',
    'head_acc': 0.7882480657351655,
    'tail_acc': 0.6994372585250724},
   {'name': 'aug',
    'head_acc': 0.788420200324021,
    'tail_acc': 0.7009134050058379}],
  'all_pass_cnt': 47624},
 {'ratio': 0.9100000000000001,
  'result': [{'name': 'baseline',
    'head_acc': 0.7838016290221294,
    'tail_acc': 0.691795170206532},
   {'name': 'balance',
    'head_acc': 0.7862925307609077,
    'tail_acc': 0.6939069925322062},
   {'name': 'aug',
    'head_acc': 0.7866368205188629,
    'tail_acc': 0.6948622829986972}],
  'all_pass_cnt': 41244},
 {'ratio': 0.9200000000000002,
  'result': [{'name': 'baseline',
    'head_acc': 0.777651236089586,
    'tail_acc': 0.7044405025868045},
   {'name': 'balance',
    'head_acc': 0.7801494496729963,
    'tail_acc': 0.7064301552106063},
   {'name': 'aug',
    'head_acc': 0.78045632557659,
    'tail_acc': 0.7077191426459334}],
  'all_pass_cnt': 33825},
 {'ratio': 0.9300000000000002,
  'result': [{'name': 'baseline',
    'head_acc': 0.7759158532915532,
    'tail_acc': 0.7015513463848684},
   {'name': 'balance',
    'head_acc': 0.7783651158791596,
    'tail_acc': 0.7037635168562826},
   {'name': 'aug',
    'head_acc': 0.778717697897475,
    'tail_acc': 0.7049438122835191}],
  'all_pass_cnt': 28298},
 {'ratio': 0.9400000000000002,
  'result': [{'name': 'baseline',
    'head_acc': 0.7752916071022069,
    'tail_acc': 0.6827163393779754},
   {'name': 'balance',
    'head_acc': 0.7778906913626707,
    'tail_acc': 0.6834914967584127},
   {'name': 'aug',
    'head_acc': 0.7780807798289091,
    'tail_acc': 0.6864183031100061}],
  'all_pass_cnt': 21286},
 {'ratio': 0.9500000000000002,
  'result': [{'name': 'baseline',
    'head_acc': 0.7721507357555836,
    'tail_acc': 0.6866389822687983},
   {'name': 'balance',
    'head_acc': 0.7746439204149146,
    'tail_acc': 0.6880693428251216},
   {'name': 'aug',
    'head_acc': 0.7749054889222656,
    'tail_acc': 0.6911607672533072}],
  'all_pass_cnt': 15171},
 {'ratio': 0.9600000000000002,
  'result': [{'name': 'baseline',
    'head_acc': 0.7694799584510404,
    'tail_acc': 0.6824891982717338},
   {'name': 'balance',
    'head_acc': 0.7719015444952468,
    'tail_acc': 0.6848175708113391},
   {'name': 'aug',
    'head_acc': 0.7723417887410061,
    'tail_acc': 0.6858137301968413}],
  'all_pass_cnt': 8332},
 {'ratio': 0.9700000000000002,
  'result': [{'name': 'baseline',
    'head_acc': 0.7680722317514641,
    'tail_acc': 0.6735136343316978},
   {'name': 'balance',
    'head_acc': 0.7705617495711676,
    'tail_acc': 0.6725748770675044},
   {'name': 'aug',
    'head_acc': 0.771017247951195,
    'tail_acc': 0.6733348234242321}],
  'all_pass_cnt': 4474},
 {'ratio': 0.9800000000000002,
  'result': [{'name': 'baseline',
    'head_acc': 0.7666836369121496,
    'tail_acc': 0.710144274120827},
   {'name': 'balance',
    'head_acc': 0.7691669495040692,
    'tail_acc': 0.7063119927862921},
   {'name': 'aug',
    'head_acc': 0.7696095900742693,
    'tail_acc': 0.7086113615870134}],
  'all_pass_cnt': 2218},
 {'ratio': 0.9900000000000002,
  'result': [{'name': 'baseline',
    'head_acc': 0.7659710180246657,
    'tail_acc': 0.793877551020407},
   {'name': 'balance',
    'head_acc': 0.7683949309662588,
    'tail_acc': 0.7949999999999989},
   {'name': 'aug',
    'head_acc': 0.7688214121682789,
    'tail_acc': 0.8031632653061216}],
  'all_pass_cnt': 980}]
lt_results.reverse()
lt_results = lt_results[2:]

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

from scipy.interpolate import make_interp_spline
from matplotlib.patches import Arc, FancyArrowPatch
from matplotlib.font_manager import FontProperties

# 定义海螺线形图的参数
num_points = len(lt_results)
# theta = np.linspace(0, 4 * np.pi, num_points)  # 角度从0到4π
theta = np.arange(0, 1/6*np.pi*num_points, 1/6*np.pi) 
r = np.linspace(0, 1, num_points)  # 半径从0到1


# 生成伪折线图数据
base_data = [item["result"][0]["tail_acc"]*100 for item in lt_results]
balanced_data = [item["result"][1]["tail_acc"]*100 for item in lt_results]
aug_data = [item["result"][2]["tail_acc"]*100 for item in lt_results] 

base_data_bak = base_data
balanced_data_bak = balanced_data
aug_data_bak = aug_data


balanced_data = [a-b for a, b in zip(balanced_data, base_data)]
aug_data = [a-b for a, b in zip(aug_data, base_data)]
rel_data =  np.linspace(0, 1.5, num_points)

balanced_data = [a+b for a, b in zip(balanced_data, rel_data)]
aug_data = [a+b for a, b in zip(aug_data, rel_data)]
# 对数据进行插值处理

theta_new = np.linspace(theta.min(), theta.max(), 300)  # 生成更多的角度数据点
rel_spl = make_interp_spline(theta, rel_data, k=3)  # 三次样条插值
balanced_spl = make_interp_spline(theta, balanced_data, k=3)  # 三次样条插值
aug_data_spl = make_interp_spline(theta, aug_data, k=3)  # 三次样条插值
rel_data_smooth = rel_spl(theta_new)
balanced_data_smooth = balanced_spl(theta_new)
aug_data_smooth = aug_data_spl(theta_new)

# spl = make_interp_spline(theta, data, k=3)  # 三次样条插值
# data_smooth = spl(theta_new)


# 创建极坐标图
fig, ax = plt.subplots(subplot_kw={'projection': 'polar'},figsize=(6.4,6.4))

base_color = "blue"
balance_color="green"
aug_color="red"

# 绘制海螺线形图
ax.plot(theta_new, rel_data_smooth,linewidth=2,color=base_color,alpha=1)
# ax.plot(theta_new, balanced_data_smooth,linewidth=2, color=balance_color,alpha=0.5)
ax.plot(theta_new, aug_data_smooth,linewidth=2, color=aug_color,alpha=0.5)
ax.plot(theta, aug_data, color=aug_color,marker='*',linestyle='None', label='ours', markersize=8)
ax.plot(theta, rel_data, color=base_color, marker='.', label='LLaVA 1.5', markersize=8,linestyle='None')
# ax.plot(theta, balanced_data, color=balance_color, marker='^',linestyle='None',label='balanced', markersize=5)


rotate_labels = [f"{i}" for i in range(2, 2+max(num_points,24), 1)]
rotate_labels_low = rotate_labels[:12]
rotate_labels_high = rotate_labels[12:24]


min_of_all = min(min(rel_data), min(balanced_data), min(aug_data))
max_of_all = max(max(rel_data), max(balanced_data), max(aug_data))

ax.set_thetagrids(angles=np.arange(0, 360, 30), labels=rotate_labels_low)
ax.set_yticklabels([])
ax.set_rgrids(np.arange(min_of_all, max_of_all, 0.5))  # 例如，设置每0.2单位一条径向网格线
font_path = './Times New Roman.ttf'
font_prop = FontProperties(fname=font_path,weight="bold")
for angle, label in zip(theta, rotate_labels_high):
    ax.text(angle,2.25, label, ha='center', va='center',fontproperties=font_prop, color='black', fontsize=14, fontweight='bold')


ax.grid(True, linestyle='-', linewidth=1,alpha=0.5)  # 添加网格线
# 创建自定义图例项
legend_elements = [
        Line2D([0], [0], color=base_color, lw=1, marker='.', markersize=8, label='LLaVA 1.5'),
        # Line2D([0], [0], color=balance_color, lw=1, marker='^', markersize=5, label='Balanced'),
        Line2D([0], [0], color=aug_color, lw=1, marker='*', markersize=5, label='Ours'),
]

plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1), ncol=3,handles=legend_elements,fontsize=15 )
specific_point_index = -1  # 要标记的点的索引
ax.text(theta[specific_point_index]+0.02, rel_data[specific_point_index],
        f'{base_data_bak[-1]:.2f}%', color=base_color, fontsize=8,
        ha='right', va='center')  # 'ha' 是水平对齐，'va' 是垂直对齐
# ax.text(theta[specific_point_index]+0.02, balanced_data[specific_point_index]-0.05,
#         f'{balanced_data_bak[-1]:.2f}%', color=balance_color, fontsize=8,
#         ha='right', va='center')  # 'ha' 是水平对齐，'va' 是垂直对齐
ax.text(theta[specific_point_index]+0.02, aug_data[specific_point_index]+0.01,
        f'{aug_data_bak[-1]:.2f}%', color=aug_color, fontsize=8,
        ha='right', va='center')  # 'ha' 是水平对齐，'va' 是垂直对齐

ax.xaxis.grid(True, color='gray', linestyle='-',linewidth=1)
ax.yaxis.grid(True, color='gray', linestyle='-',linewidth=1)

##  ARROW AND TEXT

# 设置弧的参数
r_arrow = 1.3
arrow_begin = np.pi/2
arrow_end = np.pi/6*5
theta_arc = np.linspace(arrow_begin, arrow_end, 100)  # 从 0 到 π/2 之间的弧形
r_arc = np.full_like(theta_arc, r_arrow)  # 固定半径为 1.2

# 绘制与圆边平行的弧形
ax.plot(theta_arc, r_arc, color='black', linewidth=2)

arrow = FancyArrowPatch(posA=(arrow_end-0.011, r_arrow), posB=(arrow_end+0.1, r_arrow), color='black',
                        arrowstyle='->', mutation_scale=15,linewidth=2)
ax.add_patch(arrow)
ax.text((arrow_begin+arrow_end)/2, r_arrow+0.1, 'Tail data @x%', fontsize=12, ha='center', va='center', color='black',rotation=30, rotation_mode='anchor', )

# # 定义弧形文字
# text = 'Tail data @x%'
# radius = r_arrow+0.1  # 文字距离中心的半径
# angle_start =0
# angle_span = np.pi/2

# # 将文字沿着弧形排列
# angles = np.linspace(angle_start, angle_start + angle_span, len(text))
# for i, char in enumerate(text):
#     ax.text(angles[i], radius, char,
#             ha='center', va='center',
#             rotation=angles[i] ,  # 使每个字符旋转到正确的角度
#             rotation_mode='anchor', fontsize=12, color='black')

## 径向文字
ax.text(arrow_begin-0.05, r_arrow, 'Acc', fontsize=12, ha='center', va='center', color='black',rotation=-90, rotation_mode='anchor', )

arrow = FancyArrowPatch(posA=(arrow_begin, 0), posB=(arrow_begin, 1.95), color='black',
                        arrowstyle='->', mutation_scale=15,linewidth=2)
ax.add_patch(arrow)
ax.set_rlim(0,1.95) 
ax.spines['polar'].set_linewidth(2) 

fig.savefig('./res/vqav2_llava_conch.pdf', format='pdf',bbox_inches='tight')
plt.show()

# %%
# Out:
# []
