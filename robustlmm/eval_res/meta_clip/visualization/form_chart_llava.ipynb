# %%
import os
from mhr.utils.utils import load_json_file,process_jsonl
import re
from datetime import datetime

def parse_timestamp(filename):
    # 使用正则表达式提取时间部分
    pattern = r"(\d{8})_(\d{6})_results\.json"
    match = re.match(pattern, filename)
    if match:
        date_str, time_str = match.groups()
        # 转换为 datetime 对象
        return datetime.strptime(f"{date_str} {time_str}", "%Y%m%d %H%M%S")
    else:
        return None




def read_results_from_file_new(file_path):
    res_list={}
    subdir_list = os.listdir(file_path)
    candidate = []
    for subdir in subdir_list:
        
        if os.path.isdir(os.path.join(file_path, subdir)):
            temp_res = read_results_from_file_new(os.path.join(file_path, subdir))
            # res_list.extend(temp_res)
            res_list.update(temp_res)
        else:
            result_file_flag = parse_timestamp(subdir)
            if result_file_flag:
                candidate.append({"time":result_file_flag,"path":os.path.join(file_path, subdir)})
    
    if len(candidate)>0:
        candidate = sorted(candidate,key=lambda x:x["time"])
        res_list.update(load_json_file(candidate[-1]["path"])["results"])
    return res_list

def read_results_from_file(file_path):
    if not isinstance(file_path,list):
        file_path = [file_path]
    result_dict = {}
    for path in file_path:
        if os.path.isdir(path):
            path = os.path.join(path, "results.json")
        result_dict.update(load_json_file(path)["results"])
        # result_dict.append(load_json_file(path)["results"])
    return result_dict
# baseline_file = "/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/llava/robustlmm/dr_algo/0601_2205_eval_all_llava_baseline"
# ptnft0_file = "/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/llava/robustlmm/dr_algo/0604_1109_eval_all_dr_algo_pt0_ft0"
# ptnft1_file = "/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/llava/robustlmm/dr_algo/0603_1918_eval_all_dr_algo_pt0_ft1"
# ptnft2_file = "/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/llava/robustlmm/dr_algo/0604_2258_eval_all_dr_algo_pt0_ft2"

baseline_file = "/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/0605_2135_eval_all_llava_baseline_llava_model_args_ca10f3"
ptnft0_file = "/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/0605_2135_eval_all_dr_algo_pt0_ft0_llava_model_args_d0e4fd"
ptnft1_file = "/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/0606_0113_eval_all_dr_algo_pt0_ft1_llava_model_args_cf6270"
ptnft2_file = "/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/0606_0141_eval_all_dr_algo_pt0_ft2_llava_model_args_35455f"
ptnft0add_file = "/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/0619_1510_eval_all_dr_algo_ptn_ft0_add_llava_model_args_541560"
ptnft1add_file = "/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/0626_1946_eval_all_dr_algo_ptn_ft1_add2_llava_model_args_7268ae"

ptn_one_token_file = "/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/0630_2143_eval_all_dr_algo_ptn_ft_one_token_llava_model_args_2bd817"
ptn_one_object_file = "/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/0702_0137_eval_all_dr_algo_ptn_ft_one_object_llava_model_args_27dd27"
ptn_one_co_occurrence_file = "/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/0702_0944_eval_all_dr_algo_ptn_ft_one_co_occurrence_llava_model_args_d1008e"
ptn_one_what_word_file = "/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/0702_2317_eval_all_dr_algo_ptn_ft_one_what_word_llava_model_args_cf8d49"


t_o_file = "/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/0704_0454_eval_all_dr_algo_comp_token_object_llava_model_args_adeac1"
t_c_file = "/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/0706_0946_eval_all_dr_algo_comp_token_what_word_llava_model_args_4b6a31"
t_w_file = "/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/0706_0946_eval_all_dr_algo_comp_token_what_word_llava_model_args_4b6a31"
o_c_file = "/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/0704_0105_eval_all_dr_algo_comp_object_co_occurrence_llava_model_args_0f8d0c"
o_w_file = "/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/0704_1425_eval_all_dr_algo_comp_object_what_word_llava_model_args_10d9fd"
c_w_file = "/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/0705_0739_eval_all_dr_algo_comp_co_occurrence_what_word_llava_model_args_10c1b2"

o_c_w_file="/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/0704_0251_eval_all_dr_algo_comp_object_co_occurrence_what_word_llava_model_args_7dd240"
t_c_w_file="/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/0704_1957_eval_all_dr_algo_comp_token_co_occurrence_what_word_llava_model_args_cc119e"
t_o_w_file="/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/0705_1252_eval_all_dr_algo_comp_token_object_what_word_llava_model_args_7cf8be"
t_o_c_file="/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/0706_0554_eval_all_dr_algo_comp_token_object_co_occurrence_llava_model_args_95cd35"
all_file="/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/0704_2150_eval_all_dr_algo_ptn_ft0_new_llava_model_args_be754a"


all_09_file="/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/0709_0501_eval_all_dr_algo_comp_all_0_9_llava_model_args_4ef801"
all_08_file="/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/0709_2030_eval_all_dr_algo_comp_all_0_8_llava_model_args_cd678d"
all_07_file="/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/0710_1104_eval_all_dr_algo_comp_all_0_7_llava_model_args_773628"

toc_09_file = "/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/0709_0519_eval_all_dr_algo_comp_toc_0_9_llava_model_args_46c385"
toc_08_file = "/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/0710_0045_eval_all_dr_algo_comp_toc_0_8_llava_model_args_9d9bd3"
toc_07_file = "/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/0710_1459_eval_all_dr_algo_comp_toc_0_7_llava_model_args_0464c0"

all_a08_aug_file="/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/0720_0249_all_a08_b09_aug_665k_llava_model_args_becf21"
toc_a08_aug_file="/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/0720_2138_toc_a08_b0975_aug_665k_llava_model_args_c0ba3e"
all_a1_aug_file="/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/0721_1616_all_a1_aug_665k_llava_model_args_cd7cf0"
toc_a1_aug_file="/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/0723_0541_toc_a1_aug_665k_llava_model_args_73fa2a"
all_a09_aug_file="/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/0722_1058_all_a09_aug_665k_llava_model_args_1abb51"
toc_a09_aug_file="/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/0724_0030_toc_a09_aug_665k_llava_model_args_f9c0cf"

pt_toc_ft_all_aug_file="/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/0728_0659_pt_toc_p0a1_ft_all_p0a1_aug_llava_model_args_2d5327"
tokendiff_all_p0a1_aug_file="/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/0801_1521_all_a1_aug_665k_llava_model_args_b02b18"
tokendiff_toc_p0a1_aug_file="/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/0805_2115_token...cp0a1_llava_model_args_bcb69c"
tokendiff_all_p0a09_aug_file="/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/0804_1637_all_a..._665k_llava_model_args_339918"
tokendiff_toc_p0a09_aug_file="/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/0806_0327_token...p0a09_llava_model_args_8fcf28"

replacediff_all_a1_aug_file="/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/tokenreplaceaug_alla1/0812_0037_token...alla1_llava_model_args_5b347d"
replacediff_toc_a1_aug_file="/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/tokenreplaceaug_toca1/0812_1723_token...toca1_llava_model_args_c12363"

plainaug_newcap_alla1_file="/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/plainaug_newcap_alla1/0813_1429_plain...alla1_llava_model_args_1f1d04"
plainaug_newcap_alla09_file="/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/plainaug_newcap_alla09/0813_0758_plain...lla09_llava_model_args_e6a837"
plainaug_newcap_toca1_file="/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/tokenreplaceaug_toca1/0812_1723_token...toca1_llava_model_args_c12363"

tw_lm_rewrite_diff_alla1_file="/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/alla1_tw_tail_lm_rewrite_diff/0814_2315_alla1..._diff_llava_model_args_8fc942"
tw_lm_rewrite_diff_alla09_file="/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/alla09_tw_tail_lm_rewrite_diff/0815_1539_alla0..._diff_llava_model_args_6d5143"
tw_lm_rewrite_diff_alla1_file_1to2="/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/alla1_tw_tail_lm_rewrite_diff_1to2/0816_0738_alla1..._1to2_llava_model_args_542236"
tw_lm_rewrite_diff_alla1_file_1to3="/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/alla1_tw_tail_lm_rewrite_diff_1to3/0816_2353_alla1..._1to3_llava_model_args_cf5d3f"

# alla1Aug
alla1augTokenRewrite_file="/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/0908_19_alla1augTokenRewrite_llava_model_args_c30f58"
alla1augTWRewrite_file="/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/0908_03_alla1augTWwithRewrite_llava_model_args_31ae04"
all1augImgOrigConv_file="/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/0909_22_all1augImgOrigConv_llava_model_args_400bff"

# ablation
random_sample_file="/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/0910_15_random_choice581k_llava_model_args_309626"
ablate_length_file="/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/ablate_length/0926_01_ablate_length_llava_model_args_8505fb"
ablate_el2n_file="/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/ablate_el2n/0926_20_ablate_el2n_llava_model_args_1c4027"
ablate_perplexity_file="/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/ablate_perplexity/0927_12_ablate_perplexity_llava_model_args_72b1a6"
ablate_clipscore_file="/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/ablate_clipscore/1002_15_ablate_clipscore_llava_model_args_95078a"

ablate_randomaug_file="/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/ablate_random_aug_seed42/1001_05_ablate_random_aug_seed42_llava_model_args_c2ce35"
plainaug_simple_add_file="/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/0729_1300_plainaug_simple_add_llava_model_args_91eed2"


# new
newp0a1_file="/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/new_allp0a1/0919_00_new_allp0a1_llava_model_args_153856"
new_random575k="/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/new_random575k/0919_22_new_random575k_llava_model_args_4db117"
new_baseline_file="/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/new_baseline/0920_06_new_baseline_llava_model_args_ca10f3"
newp0a1_aug_file="/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/new_augp0a1/0924_17_new_augp0a1_llava_model_args_a86c71"

#latent
latent_file = "/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/latent/exp/clusterk10_rsample_on_average/0929_01_clusterk10_rsample_on_average_llava_model_args_9ec719"
latent_selfaug_diff_llava13b_file = "/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/latent/exp/clusterk10_selfaug_diff_llava13bcap/1014_10_clusterk10_selfaug_diff_llava13bcap_llava_model_args_7a3a25"
latent_selfaug_diff_sharecaptioner_file = "/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/latent/exp/clusterk10_selfaug_diff_sharecaptionercap/1015_21_clusterk10_selfaug_diff_sharecaptionercap_llava_model_args_e34dcd"
latent_selfaug_control_llava13b_file = "/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/latent/exp/clusterk10_selfaug_control_llava13bcap/1020_18_clusterk10_selfaug_control_llava13bcap_llava_model_args_d1382e"
latent_selfaug_control_sharecaptioner_file = "/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/latent/exp/clusterk10_selfaug_control_sharecaptionercap/1021_06_clusterk10_selfaug_control_sharecaptionercap_llava_model_args_b2e5d5"

retest_aug_file = "/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/retest_synthesis581k/0929_15_retest_synthesis581k_llava_model_args_cd7cf0"
random_seed42_file = "/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/ablate_random581_seed42/0930_10_ablate_random581_seed42_llava_model_args_378339"

#control
balance581k_control_file = "/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/balance581k_control/1029_10_balance581k_control_llava_model_args_cb74df"
balance581k_control_orig_conv = "/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/balance581k_control_originconv/1114_16_balance581k_control_originconv_llava_model_args_63ea1d"
orig665k_control_aug25k  = "/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/latent/exp/orig665k_control_aug25k/1118_16_orig665k_control_aug25k_llava_model_args_0c3df5"
orig665k_control_aug50k  = "/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/latent/exp/orig665k_control_aug50k/1119_03_orig665k_control_aug50k_llava_model_args_106318"
orig665k_control_aug100k = "/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/latent/exp/orig665k_control_aug100k/1119_03_orig665k_control_aug100k_llava_model_args_9059d0"



baseline_data = read_results_from_file(baseline_file)
ptnft0_data = read_results_from_file(ptnft0_file)
ptnft1_data = read_results_from_file(ptnft1_file)
ptnft2_data = read_results_from_file(ptnft2_file)
ptnft0add_data = read_results_from_file(ptnft0add_file)
ptnf1add_data = read_results_from_file(ptnft1add_file)

ptn_one_token_data = read_results_from_file(ptn_one_token_file)
ptn_one_object_data = read_results_from_file(ptn_one_object_file)
ptn_one_co_occurrence_data = read_results_from_file(ptn_one_co_occurrence_file)
ptn_one_what_word_data = read_results_from_file(ptn_one_what_word_file)

t_o_data = read_results_from_file(t_o_file)
t_c_data = read_results_from_file(t_c_file)
t_w_data = read_results_from_file(t_w_file)
o_c_data = read_results_from_file(o_c_file)
o_w_data = read_results_from_file(o_w_file)
c_w_data = read_results_from_file(c_w_file)

o_c_w_data = read_results_from_file(o_c_w_file)
t_c_w_data = read_results_from_file(t_c_w_file)
t_o_w_data = read_results_from_file(t_o_w_file)
t_o_c_data = read_results_from_file(t_o_c_file)
all_data = read_results_from_file(all_file)

all_09_data = read_results_from_file(all_09_file)
all_08_data = read_results_from_file(all_08_file)
all_07_data = read_results_from_file(all_07_file)

toc_09_data = read_results_from_file(toc_09_file)
toc_08_data = read_results_from_file(toc_08_file)
toc_07_data = read_results_from_file(toc_07_file)

all_a08_aug_data = read_results_from_file(all_a08_aug_file)
toc_a08_aug_data = read_results_from_file(toc_a08_aug_file)
all_a1_aug_data = read_results_from_file(all_a1_aug_file)
toc_a1_aug_data = read_results_from_file(toc_a1_aug_file)
all_a09_aug_data = read_results_from_file(all_a09_aug_file)
toc_a09_aug_data = read_results_from_file(toc_a09_aug_file)

plainaug_simple_add_data = read_results_from_file(plainaug_simple_add_file)
pt_toc_ft_all_aug_data = read_results_from_file(pt_toc_ft_all_aug_file)

tokendiff_all_p0a1_aug_data = read_results_from_file(tokendiff_all_p0a1_aug_file)
tokendiff_toc_p0a1_aug_data = read_results_from_file(tokendiff_toc_p0a1_aug_file)
tokendiff_all_p0a09_aug_data = read_results_from_file(tokendiff_all_p0a09_aug_file)
tokendiff_toc_p0a09_aug_data = read_results_from_file(tokendiff_toc_p0a09_aug_file)

token_replace_all_a1_aug_data = read_results_from_file(replacediff_all_a1_aug_file)
token_replace_toc_a1_aug_data = read_results_from_file(replacediff_toc_a1_aug_file)

plainaug_newcap_alla1_data = read_results_from_file(plainaug_newcap_alla1_file)
plainaug_newcap_alla09_data = read_results_from_file(plainaug_newcap_alla09_file)
plainaug_newcap_toca1_daa = read_results_from_file(plainaug_newcap_toca1_file)

tw_lm_rewrite_diff_alla1_data = read_results_from_file(tw_lm_rewrite_diff_alla1_file)
tw_lm_rewrite_diff_alla09_data = read_results_from_file(tw_lm_rewrite_diff_alla09_file)
tw_lm_rewrite_diff_alla1_data_1to2_data = read_results_from_file(tw_lm_rewrite_diff_alla1_file_1to2)
tw_lm_rewrite_diff_alla1_data_1to3_data = read_results_from_file(tw_lm_rewrite_diff_alla1_file_1to3)

llava_base_file=[
    "/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/0605_2135_eval_all_llava_baseline_llava_model_args_ca10f3",
    "/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/supply_benchmarks/qbench_llavabase/0827_1159_qbenc...abase_llava_model_args_ca10f3",
    
]
llava_balanced_file = [
    "/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/0704_2150_eval_all_dr_algo_ptn_ft0_new_llava_model_args_be754a",
    "/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/supply_benchmarks/qbench_llavaallp0a1/0827_1207_qbenc...lp0a1_llava_model_args_be754a",
]
llava_aug_file = "/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/final_reses/llava_res/llava_aug"
llava_aug_file = [
    "/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/0721_1616_all_a1_aug_665k_llava_model_args_cd7cf0",
    "/mnt/petrelfs/songmingyang/code/tools/lmms-eval/scripts/logs/robustlmm/dr_algo/supply_benchmarks/qbench_llavaallp0a1diff/0827_1214_qbenc...1diff_llava_model_args_73fa2a",
]
# llava_aug_file = [os.path.join(llava_aug_file, f) for f in os.listdir(llava_aug_file) if os.path.isdir(os.path.join(llava_aug_file, f))]

llava_base_data = read_results_from_file(llava_base_file)
llava_balanced_data = read_results_from_file(llava_balanced_file)
llava_aug_data = read_results_from_file(llava_aug_file)

alla1augTokenRewrite_data = read_results_from_file(alla1augTokenRewrite_file)
alla1augTWRewrite_data = read_results_from_file(alla1augTWRewrite_file)
all1augImgOrigConv_data = read_results_from_file(all1augImgOrigConv_file)

random_sample_data = read_results_from_file(random_sample_file)
ablate_length_data = read_results_from_file(ablate_length_file)
ablate_el2n_data = read_results_from_file(ablate_el2n_file)
ablate_clipscore_data = read_results_from_file(ablate_clipscore_file)


newp0a1_data=read_results_from_file(newp0a1_file)
new_random575k_data=read_results_from_file(new_random575k)
new_baseline_data = read_results_from_file(new_baseline_file)
newp0a1_aug_data = read_results_from_file(newp0a1_aug_file)

#latent data
latent_exp_data = read_results_from_file(latent_file)
latent_selfaug_diff_llava13b_data = read_results_from_file(latent_selfaug_diff_llava13b_file)
latent_selfaug_diff_sharecaptioner_data = read_results_from_file(latent_selfaug_diff_sharecaptioner_file)
latent_selfaug_control_llava13b_data = read_results_from_file(latent_selfaug_control_llava13b_file)
latent_selfaug_control_sharecaptioner_data = read_results_from_file(latent_selfaug_control_sharecaptioner_file)

retest_aug_data = read_results_from_file(retest_aug_file)
random_seed42_data = read_results_from_file(random_seed42_file)
ablate_perplexity_data = read_results_from_file(ablate_perplexity_file)

ablate_randomaug_data = read_results_from_file(ablate_randomaug_file)
ablate_plainaug_simple_add_data = read_results_from_file(plainaug_simple_add_file)
balance581k_control_data = read_results_from_file(balance581k_control_file)
balance581k_control_orig_conv_data = read_results_from_file(balance581k_control_orig_conv)
orig665k_control_aug25k_data = read_results_from_file(orig665k_control_aug25k)
orig665k_control_aug50k_data = read_results_from_file(orig665k_control_aug50k)
orig665k_control_aug100k_data = read_results_from_file(orig665k_control_aug100k)


### Qwen2VL 
qwen2vl_baseline = "/mnt/petrelfs/songmingyang/code/tools/mm_eval/lmms-eval/scripts/logs/robustlmm/new_model/qwen2vl/baseline"
qwen2vl_control = "/mnt/petrelfs/songmingyang/code/tools/mm_eval/lmms-eval/scripts/logs/robustlmm/new_model/qwen2vl/control_aug"

minicpm_baseline = "/mnt/petrelfs/songmingyang/code/tools/mm_eval/lmms-eval/scripts/logs/robustlmm/new_model/minicpm_v/baseline"
minicpm_control = "/mnt/petrelfs/songmingyang/code/tools/mm_eval/lmms-eval/scripts/logs/robustlmm/new_model/minicpm_v/control_aug"

qwen2vl_baseline = read_results_from_file_new(qwen2vl_baseline)
qwen2vl_control = read_results_from_file_new(qwen2vl_control)

minicpm_baseline = read_results_from_file_new(minicpm_baseline)
minicpm_control = read_results_from_file_new(minicpm_control)

# %%
metric_list = ["vqav2","gqa","vizwiz_vqa","scienceqa_img","pope","mme","seedbench","seedbench-2","refcoco","refcoco+","mmmu"]
metric1_list = ["vqav2","textvqa","ok_vqa","gqa","vizwiz_vqa","scienceqa","scienceqa_img","refcoco","refcoco+","flickr30k","pope","seedbench","mmmu"]
metric2_list = ["pope","mme","seedbench","seedbench-2","mmbench_en_dev","mmbench_cn_dev","llava_bench_coco","llava_in_the_wild","mmmu"]
metric2_list = ["pope","mme","seedbench","seedbench-2","mmmu"]

detailed_main_res_list = ["ok_vqa","seedbench-2","qbench2_dev","mmstar","mme","scienceqa_img","mmmu","textvqa","gqa","mmbench_en_dev","vqav2"]

#VQAv2 VQAT VQAOK GQA VisWiz SQA SQAI REF REF+ FLIK POPE MMEP SEED SEEDv2 MMMU
ablation_comb_list=["vqav2","textvqa","ok_vqa","gqa","vizwiz_vqa","scienceqa","scienceqa_img","refcoco","refcoco+","flickr30k","pope","seedbench","seedbench-2","mmmu"]
ablation_comb_list=["vqav2","textvqa","ok_vqa","gqa","scienceqa","scienceqa_img","refcoco","refcoco+","flickr30k","pope","seedbench"]

#VQAv2 GQA VizWiz SQII VQAT POPE MME MMB MMBCN
metric_balance_list = ["vqav2","gqa","vizwiz_vqa","scienceqa_img","textvqa","pope","mme","mmbench_en_dev","mmbench_cn_dev"]
metric_excel_list = ["vqav2","textvqa","ok_vqa","gqa","vizwiz_vqa","scienceqa","scienceqa_img","refcoco_bbox_val","refcoco_seg_val","refcoco+_bbox_val",
                     "refcoco+_seg_val","flickr30k","pope","seedbench","mmmu","mmbench_en_dev","mmbench_cn_dev","mmstar","seedbench_2","mme","mmec",
                     "qbench_dev","qbench2_dev","abench_dev"]

metric_main_tab = ["vqav2","scienceqa_img","mmmu","mme","mmstar","textvqa","gqa","qbench2_dev","ok_vqa","mmbench_en_dev"]
metric_dict = {
    "vqav2": ["exact_match,none"],
    "textvqa": ["exact_match,none"],
    "gqa":["exact_match,none"],
    "mme":["mme_percetion_score,none"],
    "mmec":["mme_cognition_score,none"],
    "mmmu":["mmmu_acc,none"],
    "pope":["pope_accuracy,none"],
    "refcoco":["refcoco_CIDEr,none"],
    "refcoco+":["refcoco_CIDEr,none"],
    "refcoco_bbox_val":["refcoco_CIDEr,none"],
    "refcoco_seg_val":["refcoco_CIDEr,none"],
    "refcoco+_bbox_val":["refcoco_CIDEr,none"],
    "refcoco+_seg_val":["refcoco_CIDEr,none"],
    "scienceqa":["exact_match,none"],
    "scienceqa_img":["exact_match,none"],
    "seedbench":["seed_all,none"],
    "seedbench-2":["seed_all,none"],
    "seedbench_2":["seed_all,none"],
    "vizwiz_vqa":["exact_match,none"],
    "flickr30k":["flickr_CIDEr,none"],
    "hallusion_bench_image":["aAcc,none"],
    "llava_bench_coco":["gpt_eval_llava_all,none"],
    "llava_in_the_wild":["gpt_eval_llava_all,none"],
    "mmbench_cn_dev":["gpt_eval_score,none"],
    "mmbench_en_dev":["gpt_eval_score,none"],
    "mmvet":["gpt_eval_score,none"],
    "ok_vqa":["exact_match,none"],
    "textvqa":["exact_match,none"],
    "qbench_dev":["qbench_acc,none"],
    "qbench2_dev":["qbench_acc,none"],
    "abench_dev":["abench_acc,none"],
    "mmstar":["average,none"]
}
mmstar_basic_list=["coarse perception,none","fine-grained perception,none","instance reasoning,none","logical reasoning,none","science & technology,none","math,none"]

alias_dict = {
    "flickr30k":"flickr30k_test",
    "mmmu":"mmmu_val",
    "ok_vqa":"ok_vqa_val2014",
    "scienceqa":"scienceqa_full",
    "textvqa":"textvqa_val",
    "vizwiz_vqa":"vizwiz_vqa_val",
    "vqav2":"vqav2_val",
    "seedbench_2":"seedbench-2",
    "seedbench-2":"seedbench_2",
    "mmec":"mme"
}
llava_paper_dict=dict(
    # vqav2=78.5,
    gqa=62.0,
    vizwiz_vqa=50.0,
    scienceqa_img=66.8,
    # textvqa=58.2,
    pope=85.9,
    # mme=1510.7,
    mmbench_en_dev=64.3,
    # mmbench_cn_dev=58.3,
    # seedbench=58.6,
    llava_in_the_wild=63.4,
    mmvet=30.5,
)


baseline_train_data = "/mnt/petrelfs/songmingyang/songmingyang/data/llava_train/LLaVA-Instruct-150K/reformed_data/origin_data/llava_v1_5_mix665k.json"
ft0_train_data = "/mnt/petrelfs/songmingyang/songmingyang/data/llava_train/LLaVA-Instruct-150K/reformed_data/dr_algo/llava_v1_5_mix665k_meta_p0.json"
ft1_train_data = "/mnt/petrelfs/songmingyang/songmingyang/data/llava_train/LLaVA-Instruct-150K/reformed_data/dr_algo/llava_v1_5_mix665k_meta_p1.json"
ft2_train_data = "/mnt/petrelfs/songmingyang/songmingyang/data/llava_train/LLaVA-Instruct-150K/reformed_data/dr_algo/llava_v1_5_mix665k_meta_p2.json"
ft0add_train_data = "/mnt/petrelfs/songmingyang/songmingyang/data/llava_train/LLaVA-Instruct-150K/reformed_data/dr_algo/add/llava_v1_5_mix665k_meta_add_p0.json"
ft1add_train_data = "/mnt/petrelfs/songmingyang/songmingyang/data/llava_train/LLaVA-Instruct-150K/reformed_data/dr_algo/add/llava_v1_5_mix665k_meta_add_p1.json"
ftn_one_token_train_data = "/mnt/petrelfs/songmingyang/songmingyang/data/llava_train/LLaVA-Instruct-150K/reformed_data/dr_algo/one/llava_v1_5_mix665k_meta_one_ktoken.json"
ftn_one_object_train_data = "/mnt/petrelfs/songmingyang/songmingyang/data/llava_train/LLaVA-Instruct-150K/reformed_data/dr_algo/one/llava_v1_5_mix665k_meta_one_kobject.json"
ftn_one_co_occurrence_train_data = "/mnt/petrelfs/songmingyang/songmingyang/data/llava_train/LLaVA-Instruct-150K/reformed_data/dr_algo/one/llava_v1_5_mix665k_meta_one_kco_occurrence.json"
ftn_one_what_word_train_data = "/mnt/petrelfs/songmingyang/songmingyang/data/llava_train/LLaVA-Instruct-150K/reformed_data/dr_algo/one/llava_v1_5_mix665k_meta_one_kwhat_word.json"

t_o_train_data="/mnt/petrelfs/songmingyang/songmingyang/data/llava_train/LLaVA-Instruct-150K/reformed_data/dr_algo/compose/llava_v1_5_mix665k_meta_c_token_object.json"
t_c_train_data="/mnt/petrelfs/songmingyang/songmingyang/data/llava_train/LLaVA-Instruct-150K/reformed_data/dr_algo/compose/llava_v1_5_mix665k_meta_c_token_co_occurrence.json"
t_w_train_data="/mnt/petrelfs/songmingyang/songmingyang/data/llava_train/LLaVA-Instruct-150K/reformed_data/dr_algo/compose/llava_v1_5_mix665k_meta_c_token_what_word.json"
o_c_train_data="/mnt/petrelfs/songmingyang/songmingyang/data/llava_train/LLaVA-Instruct-150K/reformed_data/dr_algo/compose/llava_v1_5_mix665k_meta_c_object_co_occurrence.json"
o_w_train_data="/mnt/petrelfs/songmingyang/songmingyang/data/llava_train/LLaVA-Instruct-150K/reformed_data/dr_algo/compose/llava_v1_5_mix665k_meta_c_object_what_word.json"
c_w_train_data="/mnt/petrelfs/songmingyang/songmingyang/data/llava_train/LLaVA-Instruct-150K/reformed_data/dr_algo/compose/llava_v1_5_mix665k_meta_c_co_occurrence_what_word.json"

o_c_w_train_data="/mnt/petrelfs/songmingyang/songmingyang/data/llava_train/LLaVA-Instruct-150K/reformed_data/dr_algo/compose/llava_v1_5_mix665k_meta_c_object_co_occurrence_what_word.json"
t_c_w_train_data="/mnt/petrelfs/songmingyang/songmingyang/data/llava_train/LLaVA-Instruct-150K/reformed_data/dr_algo/compose/llava_v1_5_mix665k_meta_c_token_co_occurrence_what_word.json"
t_o_w_train_data="/mnt/petrelfs/songmingyang/songmingyang/data/llava_train/LLaVA-Instruct-150K/reformed_data/dr_algo/compose/llava_v1_5_mix665k_meta_c_token_object_what_word.json"
t_o_c_train_data="/mnt/petrelfs/songmingyang/songmingyang/data/llava_train/LLaVA-Instruct-150K/reformed_data/dr_algo/compose/llava_v1_5_mix665k_meta_c_token_object_co_occurrence.json"
all_train_data="/mnt/petrelfs/songmingyang/songmingyang/data/llava_train/LLaVA-Instruct-150K/reformed_data/dr_algo/compose/llava_v1_5_mix665k_meta_c_token_object_co_occurrence_what_word.json"

all_09_train_data="/mnt/petrelfs/songmingyang/songmingyang/data/llava_train/LLaVA-Instruct-150K/reformed_data/dr_algo/compose_alpha/llava_v1_5_mix665k_meta_all_p0_alpha_0.9.json"
all_08_train_data="/mnt/petrelfs/songmingyang/songmingyang/data/llava_train/LLaVA-Instruct-150K/reformed_data/dr_algo/compose_alpha/llava_v1_5_mix665k_meta_all_p0_alpha_0.8.json"
all_07_train_data="/mnt/petrelfs/songmingyang/songmingyang/data/llava_train/LLaVA-Instruct-150K/reformed_data/dr_algo/compose_alpha/llava_v1_5_mix665k_meta_all_p0_alpha_0.7.json"

toc_09_train_data="/mnt/petrelfs/songmingyang/songmingyang/data/llava_train/LLaVA-Instruct-150K/reformed_data/dr_algo/compose_alpha/llava_v1_5_mix665k_meta_toc_p0_alpha_0.9.json"
toc_08_train_data="/mnt/petrelfs/songmingyang/songmingyang/data/llava_train/LLaVA-Instruct-150K/reformed_data/dr_algo/compose_alpha/llava_v1_5_mix665k_meta_toc_p0_alpha_0.8.json"
toc_07_train_data="/mnt/petrelfs/songmingyang/songmingyang/data/llava_train/LLaVA-Instruct-150K/reformed_data/dr_algo/compose_alpha/llava_v1_5_mix665k_meta_toc_p0_alpha_0.7.json"

all_a08_aug_train_data="/mnt/petrelfs/songmingyang/songmingyang/data/llava_train/LLaVA-Instruct-150K/reformed_data/dr_algo/aug/train_data/llava_all_p0_a0.8_aug200k.json"
toc_a08_aug_train_data="/mnt/petrelfs/songmingyang/songmingyang/data/llava_train/LLaVA-Instruct-150K/reformed_data/dr_algo/aug/train_data/llava_toc_p0_a0.8_b0.975_aug200k.json"
all_a1_aug_train_data="/mnt/petrelfs/songmingyang/songmingyang/data/llava_train/LLaVA-Instruct-150K/reformed_data/dr_algo/aug/train_data/llava_all_p0_a1_b0.38_aug665k.json"
toc_a1_aug_train_data="/mnt/petrelfs/songmingyang/songmingyang/data/llava_train/LLaVA-Instruct-150K/reformed_data/dr_algo/aug/train_data/llava_toc_p0_a1_b0.47_aug665k.json"
all_a09_aug_train_data="/mnt/petrelfs/songmingyang/songmingyang/data/llava_train/LLaVA-Instruct-150K/reformed_data/dr_algo/aug/train_data/llava_all_p0_a0.9_b0.64_aug665k.json"
toc_a09_aug_train_data="/mnt/petrelfs/songmingyang/songmingyang/data/llava_train/LLaVA-Instruct-150K/reformed_data/dr_algo/aug/train_data/llava_toc_p0_a0.9_b0.72_aug665k.json"

pt_tocp0a1_train_data="/mnt/petrelfs/songmingyang/songmingyang/data/llava_train/LLaVA-LCS-558K/dr_algo/train_data/llava_meta_toc_p0_a1.json"

plainaug_simple_add_train_data="/mnt/petrelfs/songmingyang/songmingyang/data/llava_train/LLaVA-Instruct-150K/reformed_data/dr_algo/plain_aug/train_data/plain_aug_simple_add.json"

token_replace_all_a1_aug_train_data="/mnt/petrelfs/songmingyang/songmingyang/data/llava_train/LLaVA-Instruct-150K/reformed_data/dr_algo/aug/token_aug/syn_replace/train_data/llavaft_replacediffaug_allp0a1.json"
token_replace_toc_a1_aug_train_data="/mnt/petrelfs/songmingyang/songmingyang/data/llava_train/LLaVA-Instruct-150K/reformed_data/dr_algo/aug/token_aug/syn_replace/train_data/llavaft_replacediffaug_tocp0a1.json"

ft0_train_data_length = 561.6*1000
ft1_train_data_length = 242.2*1000
ft2_train_data_length = 125.8*1000
ft0add_train_data_length = 1242.2*1000
ft1add_train_data_length = 558.0*1000
ftn_one_token_train_data_length = 488.1*1000
ftn_one_object_train_data_length = 197.9*1000
ftn_one_co_occurrence_train_data_length = 242.4*1000
ftn_one_what_word_train_data_length = 176.3*1000

t_o_length=534.2*1000
t_c_length= 553.4*1000
t_w_length=521.5*1000
o_c_length=276.9*1000
o_w_length=318.3*1000
c_w_length= 349.9*1000

o_c_w_length=375.9*1000
t_c_w_length=575.5*1000
t_o_w_length=559.3*1000
t_o_c_length= 561.5*1000
all_length= 581.7*1000

all_09_length= 523.7*1000
all_08_length= 465.1*1000
all_07_length= 407.4*1000

toc_09_length= 505.4*1000
toc_08_length= 449.5*1000
toc_07_length= 393.5*1000

all_a08_aug_length=664.3*1000
toc_a08_aug_length=665.4*1000
all_a1_aug_length=665.7*1000
toc_a1_aug_length=665.3*1000
all_a09_aug_length=665.3*1000
toc_a09_aug_length=664.7*1000
base_length=665.3*1000

# pt_tocp0a1_length = len(load_json_file(pt_tocp0a1_train_data))
plainaug_simple_add_length = 665.3*1000
tokendiff_all_p0a1_aug_train_data = "/mnt/petrelfs/songmingyang/songmingyang/data/llava_train/LLaVA-Instruct-150K/reformed_data/dr_algo/aug/token_aug/train_data/llavaft_allp0a1_tokendiffaug.json"
tokendiff_toc_p0a1_aug_train_data = "/mnt/petrelfs/songmingyang/songmingyang/data/llava_train/LLaVA-Instruct-150K/reformed_data/dr_algo/aug/token_aug/train_data/llavaft_tocp0a1_tokendiffaug.json"
tokendiff_all_p0a09_aug_train_data = "/mnt/petrelfs/songmingyang/songmingyang/data/llava_train/LLaVA-Instruct-150K/reformed_data/dr_algo/aug/token_aug/train_data/llavaft_allp0a09_tokendiffaug.json"
tokendiff_toc_p0a09_aug_train_data = "/mnt/petrelfs/songmingyang/songmingyang/data/llava_train/LLaVA-Instruct-150K/reformed_data/dr_algo/aug/token_aug/train_data/llavaft_tocp0a09_tokendiffaug.json"
plainaug_newcap_alla09_train_data = ""

tokendiff_all_p0a1_aug_length=665.2*1000
tokendiff_toc_p0a1_aug_length=665.2*1000
tokendiff_all_p0a09_aug_length=665.2*1000
tokendiff_toc_p0a09_aug_length=665.3*1000
replacediff_all_a1_aug_length=665.3*1000
replacediff_toc_a1_aug_length=665.3*1000

plainaug_newcap_alla09_length=665.3*1000
plainaug_newcap_alla1_length=665.3*1000
plainaug_newcap_toca1_length=665.3*1000

# %%
method_dict = {
    "baseline":{"data":baseline_data,"ft_length":f"{base_length/1000 :.1f}K","pt_length":f"{558 :.1f}K"},
    # "PTNFT0":{"data":ptnft0_data,"ft_length":f"{ft0_train_data_length/1000 :.1f}K","pt_length":f"{558 :.1f}K"},
    # "PTNFT1":{"data":ptnft1_data,"ft_length":f"{ft1_train_data_length/1000 :.1f}K","pt_length":f"{558 :.1f}K"},
    # "PTNFT2":{"data":ptnft2_data,"ft_length":f"{ft2_train_data_length/1000 :.1f}K","pt_length":f"{558 :.1f}K"},
    # "PTNFT0ADD":{"data":ptnft0add_data,"ft_length":f"{ft0add_train_data_length/1000 :.1f}K","pt_length":f"{558 :.1f}K"},
    # "PTNFT1ADD":{"data":ptnf1add_data,"ft_length":f"{ft1add_train_data_length/1000 :.1f}K","pt_length":f"{558 :.1f}K"},
    # "object":dict(data=ptn_one_object_data,ft_length=f"{ftn_one_object_train_data_length/1000 :.1f}K",pt_length=f"{558 :.1f}K"),
    # "token":dict(data=ptn_one_token_data,ft_length=f"{ftn_one_token_train_data_length/1000 :.1f}K",pt_length=f"{558 :.1f}K"),
    # "co-occurrence":dict(data=ptn_one_co_occurrence_data,ft_length=f"{ftn_one_co_occurrence_train_data_length/1000 :.1f}K",pt_length=f"{558 :.1f}K"),
    # "what word":dict(data=ptn_one_what_word_data,ft_length=f"{ftn_one_what_word_train_data_length/1000 :.1f}K",pt_length=f"{558 :.1f}K"),
    # "T O":dict(data=t_o_data,ft_length=f"{t_o_length/1000 :.1f}K",pt_length=f"{558 :.1f}K"),
    # "T C":dict(data=t_c_data,ft_length=f"{t_c_length/1000 :.1f}K",pt_length=f"{558 :.1f}K"),
    # "T W":dict(data=t_w_data,ft_length=f"{t_w_length/1000 :.1f}K",pt_length=f"{558 :.1f}K"),
    # "O C":dict(data=o_c_data,ft_length=f"{o_c_length/1000 :.1f}K",pt_length=f"{558 :.1f}K"),
    # "O W":dict(data=o_w_data,ft_length=f"{o_w_length/1000 :.1f}K",pt_length=f"{558 :.1f}K"),
    # "C W":dict(data=c_w_data,ft_length=f"{c_w_length/1000 :.1f}K",pt_length=f"{558 :.1f}K"),
    # "O C W":dict(data=o_c_w_data,ft_length=f"{o_c_w_length/1000 :.1f}K",pt_length=f"{558 :.1f}K"),
    # "T C W":dict(data=t_c_w_data,ft_length=f"{t_c_w_length/1000 :.1f}K",pt_length=f"{558 :.1f}K"),
    # "T O W":dict(data=t_o_w_data,ft_length=f"{t_o_w_length/1000 :.1f}K",pt_length=f"{558 :.1f}K"),
    # "T O C":dict(data=t_o_c_data,ft_length=f"{t_o_c_length/1000 :.1f}K",pt_length=f"{558 :.1f}K"),
    # "ALL":dict(data=all_data,ft_length=f"{all_length/1000 :.1f}K",pt_length=f"{558 :.1f}K"),
    "all+$\\alpha=1.0$":dict(data=all_data,ft_length=f"{all_length/1000 :.1f}K",pt_length=f"{558 :.1f}K"),
    "all+$\\alpha=0.9$":dict(data=all_09_data,ft_length=f"{all_09_length/1000 :.1f}K",pt_length=f"{558 :.1f}K"),
    # "all+$\\alpha=0.8$":dict(data=all_08_data,ft_length=f"{all_08_length/1000 :.1f}K",pt_length=f"{558 :.1f}K"),
    # "all+$\\alpha=0.7$":dict(data=all_07_data,ft_length=f"{all_07_length/1000 :.1f}K",pt_length=f"{558 :.1f}K"),
    # "toc+$\\alpha=1.0$":dict(data=t_o_c_data,ft_length=f"{t_o_c_length/1000 :.1f}K",pt_length=f"{558 :.1f}K"),
    # "toc+$\\alpha=0.9$":dict(data=toc_09_data,ft_length=f"{toc_09_length/1000 :.1f}K",pt_length=f"{558 :.1f}K"),
    # "toc+$\\alpha=0.8$":dict(data=toc_08_data,ft_length=f"{toc_08_length/1000 :.1f}K",pt_length=f"{558 :.1f}K"),
    # "toc+$\\alpha=0.7$":dict(data=toc_07_data,ft_length=f"{toc_07_length/1000 :.1f}K",pt_length=f"{558 :.1f}K"),
    # "all+$\\alpha=0.8$+aug":dict(data=all_a08_aug_data,ft_length=f"{all_a08_aug_length/1000 :.1f}K",pt_length=f"{558 :.1f}K"),
    # "toc+$\\alpha=0.8$+aug":dict(data=toc_a08_aug_data,ft_length=f"{toc_a08_aug_length/1000 :.1f}K",pt_length=f"{558 :.1f}K"),
    "all+$\\alpha=1.0$+aug":dict(data=all_a1_aug_data,ft_length=f"{all_a1_aug_length/1000 :.1f}K",pt_length=f"{558 :.1f}K"),
    # "toc+$\\alpha=1.0$+aug":dict(data=toc_a1_aug_data,ft_length=f"{toc_a1_aug_length/1000 :.1f}K",pt_length=f"{558 :.1f}K"),
    "all+$\\alpha=0.9$+aug":dict(data=all_a09_aug_data,ft_length=f"{all_a09_aug_length/1000 :.1f}K",pt_length=f"{558 :.1f}K"),
    # "toc+$\\alpha=0.9$+aug":dict(data=toc_a09_aug_data,ft_length=f"{toc_a09_aug_length/1000 :.1f}K",pt_length=f"{558 :.1f}K"),
    "all+$\\alpha=1.0$+tokendiff":dict(data=tokendiff_all_p0a1_aug_data,ft_length=f"{tokendiff_all_p0a1_aug_length/1000 :.1f}K",pt_length=f"{558 :.1f}K"),
    "all+$\\alpha=0.9$+tokendiff":dict(data=tokendiff_all_p0a09_aug_data,ft_length=f"{tokendiff_all_p0a09_aug_length/1000 :.1f}K",pt_length=f"{558 :.1f}K"),
    # "toc+$\\alpha=1.0$+tokendiff":dict(data=tokendiff_toc_p0a1_aug_data,ft_length=f"{tokendiff_toc_p0a1_aug_length/1000 :.1f}K",pt_length=f"{558 :.1f}K"),
    # "toc+$\\alpha=0.9$+tokendiff":dict(data=tokendiff_toc_p0a09_aug_data,ft_length=f"{tokendiff_toc_p0a09_aug_length/1000 :.1f}K",pt_length=f"{558 :.1f}K"),
    "all+$\\alpha=1.0$+replacediff":dict(data=token_replace_all_a1_aug_data,ft_length=f"{replacediff_all_a1_aug_length/1000 :.1f}K",pt_length=f"{558 :.1f}K"),  
    # "toc+$\\alpha=1.0$+replacediff":dict(data=token_replace_toc_a1_aug_data,ft_length=f"{replacediff_toc_a1_aug_length/1000 :.1f}K",pt_length=f"{558 :.1f}K"),
    "all+$\\alpha=1.0$+plainaug simpleadd":dict(data=plainaug_simple_add_data,ft_length=f"{plainaug_simple_add_length/1000 :.1f}K",pt_length=f"{558 :.1f}K"),
    "all+$\\alpha=0.9$+plainaug newcap":dict(data=plainaug_newcap_alla09_data,ft_length=f"{plainaug_newcap_alla09_length/1000 :.1f}K",pt_length=f"{558 :.1f}K"),
    "all+$\\alpha=1.0$+plainaug newcap":dict(data=plainaug_newcap_alla1_data,ft_length=f"{plainaug_newcap_alla1_length/1000 :.1f}K",pt_length=f"{558 :.1f}K"),
    # "toc+$\\alpha=1.0$+plainaug":dict(data=plainaug_newcap_toca1_daa,ft_length=f"{plainaug_newcap_toca1_length/1000 :.1f}K",pt_length=f"{558 :.1f}K"),
    "all+$\\alpha=1.0$+rewrite diff":dict(data=tw_lm_rewrite_diff_alla1_data,ft_length=f"{665.3 :.1f}K",pt_length=f"{558 :.1f}K"),
    "all+$\\alpha=0.9$+rewrite diff":dict(data=tw_lm_rewrite_diff_alla09_data,ft_length=f"{665.3 :.1f}K",pt_length=f"{558 :.1f}K"),
    "all+$\\alpha=1.0$+rewrite diff 1to2":dict(data=tw_lm_rewrite_diff_alla1_data_1to2_data,ft_length=f"{665.3 :.1f}K",pt_length=f"{558 :.1f}K"),
    "all+$\\alpha=1.0$+rewrite diff 1to3":dict(data=tw_lm_rewrite_diff_alla1_data_1to3_data,ft_length=f"{665.3 :.1f}K",pt_length=f"{558 :.1f}K"),
}

method_dict_tocw = {
    f"\\multicolumn{{4}}{{c|}}{{baseline}}":{"data":baseline_data,"ft_length":f"{665 :.1f}K","pt_length":f"{558 :.1f}K"},
    f"\\checkmark & & & ":dict(data=ptn_one_token_data,ft_length=f"{ftn_one_token_train_data_length/1000 :.1f}K",pt_length=f"{558 :.1f}K"),
    f" & \\checkmark& & ":dict(data=ptn_one_object_data,ft_length=f"{ftn_one_object_train_data_length/1000 :.1f}K",pt_length=f"{558 :.1f}K"),
    f" & &\\checkmark & ":dict(data=ptn_one_co_occurrence_data,ft_length=f"{ftn_one_co_occurrence_train_data_length/1000 :.1f}K",pt_length=f"{558 :.1f}K"),
    f" & & &\\checkmark ":dict(data=ptn_one_what_word_data,ft_length=f"{ftn_one_what_word_train_data_length/1000 :.1f}K",pt_length=f"{558 :.1f}K"),
    f"\\checkmark & \\checkmark & & ":dict(data=t_o_data,ft_length=f"{t_o_length/1000 :.1f}K",pt_length=f"{558 :.1f}K"),
    f"\\checkmark &  & \\checkmark & ":dict(data=t_c_data,ft_length=f"{t_c_length/1000 :.1f}K",pt_length=f"{558 :.1f}K"),
    f"\\checkmark &  & & \\checkmark ":dict(data=t_w_data,ft_length=f"{t_w_length/1000 :.1f}K",pt_length=f"{558 :.1f}K"),
    f" & \\checkmark & \\checkmark & ":dict(data=o_c_data,ft_length=f"{o_c_length/1000 :.1f}K",pt_length=f"{558 :.1f}K"),
    f" &  \\checkmark & & \\checkmark ":dict(data=o_w_data,ft_length=f"{o_w_length/1000 :.1f}K",pt_length=f"{558 :.1f}K"),
    f" & & \\checkmark &  \\checkmark ":dict(data=c_w_data,ft_length=f"{c_w_length/1000 :.1f}K",pt_length=f"{558 :.1f}K"),
    f" & \\checkmark & \\checkmark &  \\checkmark ":dict(data=o_c_w_data,ft_length=f"{o_c_w_length/1000 :.1f}K",pt_length=f"{558 :.1f}K"),
    f" \\checkmark &  & \\checkmark &  \\checkmark ":dict(data=t_c_w_data,ft_length=f"{t_c_w_length/1000 :.1f}K",pt_length=f"{558 :.1f}K"),
    f" \\checkmark &\\checkmark  &  &  \\checkmark ":dict(data=t_o_w_data,ft_length=f"{t_o_w_length/1000 :.1f}K",pt_length=f"{558 :.1f}K"),
    f" \\checkmark &\\checkmark  & \\checkmark &   ":dict(data=t_o_c_data,ft_length=f"{t_o_c_length/1000 :.1f}K",pt_length=f"{558 :.1f}K"),
    f" \\checkmark &\\checkmark  & \\checkmark &  \\checkmark ":dict(data=all_data,ft_length=f"{all_length/1000 :.1f}K",pt_length=f"{558 :.1f}K"),
}

balance_method_dict = {
    "baseline":{"data":new_baseline_data,"ft_length":f"{665 :.1f}K","pt_length":f"{558 :.1f}K"},
    "random":{"data":random_sample_data,"ft_length":f"{581 :.1f}K","pt_length":f"{558 :.1f}K"},
    "ramdomseed42":{"data":random_seed42_data,"ft_length":f"{581 :.1f}K","pt_length":f"{558 :.1f}K"},
    "length":{"data":ablate_length_data,"ft_length":f"{581 :.1f}K","pt_length":f"{558 :.1f}K"},
    "el2n":{"data":ablate_el2n_data,"ft_length":f"{581 :.1f}K","pt_length":f"{558 :.1f}K"},
    "perplexity":{"data":ablate_perplexity_data,"ft_length":f"{581 :.1f}K","pt_length":f"{558 :.1f}K"},
    "clipscore":{"data":ablate_clipscore_data,"ft_length":f"{581 :.1f}K","pt_length":f"{558 :.1f}K"},
    "balanced":{"data":llava_balanced_data,"ft_length":f"{581 :.1f}K","pt_length":f"{558 :.1f}K"},
    
    "ours":{"data":llava_aug_data,"ft_length":f"{665 :.1f}K","pt_length":f"{558 :.1f}K"},
}
paper_balance_method_dict = {
    "baseline":{"data":new_baseline_data,"ft_length":f"{665 :.1f}K","pt_length":f"{558 :.1f}K"},
    "random":{"data":random_sample_data,"ft_length":f"{581 :.1f}K","pt_length":f"{558 :.1f}K"},
    "perplexity":{"data":ablate_perplexity_data,"ft_length":f"{581 :.1f}K","pt_length":f"{558 :.1f}K"},
    "randomaug":{"data":ablate_randomaug_data,"ft_length":f"{665 :.1f}K","pt_length":f"{558 :.1f}K"},
    "simpleaug":{"data":ablate_plainaug_simple_add_data,"ft_length":f"{665 :.1f}K","pt_length":f"{558 :.1f}K"},
    "balance":{"data":llava_balanced_data,"ft_length":f"{581 :.1f}K","pt_length":f"{558 :.1f}K"},
    "ours":{"data":llava_aug_data,"ft_length":f"{665 :.1f}K","pt_length":f"{558 :.1f}K"},
    "ours_new":{"data":newp0a1_aug_data,"ft_length":f"{665 :.1f}K","pt_length":f"{558 :.1f}K"},
    "ours_control":{"data":balance581k_control_data,"ft_length":f"{665 :.1f}K","pt_length":f"{558 :.1f}K"},
    "ours_control_orig_conv":{"data":balance581k_control_orig_conv_data,"ft_length":f"{665 :.1f}K","pt_length":f"{558 :.1f}K"},
    "orig665k_control_aug25k":{"data":orig665k_control_aug25k_data,"ft_length":f"{665 :.1f}K","pt_length":f"{558 :.1f}K"},
    "orig665k_control_aug50k":{"data":orig665k_control_aug50k_data,"ft_length":f"{665 :.1f}K","pt_length":f"{558 :.1f}K"},
    "orig665k_control_aug100k":{"data":orig665k_control_aug100k_data,"ft_length":f"{665 :.1f}K","pt_length":f"{558 :.1f}K"},
}

method_dict_ablation_on_aug = {
    "baseline":{"data":baseline_data,"ft_length":f"{base_length/1000 :.1f}K","pt_length":f"{558 :.1f}K"},
    "ALL":dict(data=all_a1_aug_data,ft_length=f"{665 :.1f}K",pt_length=f"{558 :.1f}K"),
    "Image Only":dict(data=all1augImgOrigConv_data,ft_length=f"{665 :.1f}K",pt_length=f"{558 :.1f}K"),
    "Token Rewrite":dict(data=alla1augTokenRewrite_data,ft_length=f"{665 :.1f}K",pt_length=f"{558 :.1f}K"),
    "TW Rewrite":dict(data=alla1augTWRewrite_data,ft_length=f"{665 :.1f}K",pt_length=f"{558 :.1f}K"),
    "PlainAug SimpAdd":dict(data=plainaug_simple_add_data,ft_length=f"{plainaug_simple_add_length/1000 :.1f}K",pt_length=f"{558 :.1f}K"),
    "PlainAug NewCap":dict(data=plainaug_newcap_alla1_data,ft_length=f"{plainaug_newcap_alla1_length/1000 :.1f}K",pt_length=f"{558 :.1f}K"),
}
new_method_dict = {
    "baseline":{"data":new_baseline_data,"ft_length":f"{665 :.1f}K","pt_length":f"{558 :.1f}K"},
    "random":{"data":new_random575k_data,"ft_length":f"{575 :.1f}K","pt_length":f"{558 :.1f}K"},
    "balanced":{"data":newp0a1_data,"ft_length":f"{575 :.1f}K","pt_length":f"{558 :.1f}K"},
    "ours":{"data":newp0a1_aug_data,"ft_length":f"{665 :.1f}K","pt_length":f"{558 :.1f}K"},
    
}
latent_method_dict = {
    "baseline":{"data":new_baseline_data, "ft_length":f"{665 :.1f}K","pt_length":f"{558 :.1f}K"},
    "latent_bal":{"data":latent_exp_data, "ft_length":f"{665 :.1f}K","pt_length":f"{558 :.1f}K"},
    "latent_diff_llava13b":{"data":latent_selfaug_diff_llava13b_data, "ft_length":f"{665 :.1f}K","pt_length":f"{558 :.1f}K"},
    "latent_diff_sharecaptioner":{"data":latent_selfaug_diff_sharecaptioner_data, "ft_length":f"{665 :.1f}K","pt_length":f"{558 :.1f}K"},
    "latent_selfaug_control_llava13b":{"data":latent_selfaug_control_llava13b_data, "ft_length":f"{665 :.1f}K","pt_length":f"{558 :.1f}K"},
    "latent_selfaug_control_sharecaptioner":{"data":latent_selfaug_control_sharecaptioner_data, "ft_length":f"{665 :.1f}K","pt_length":f"{558 :.1f}K"},
}

qwen2vl_method_dict = {
    "qwen2vl":{"data":qwen2vl_baseline, "ft_length":f"{665 :.1f}K","pt_length":f"{558 :.1f}K"},
    "qwen2vl_aug":{"data":qwen2vl_control, "ft_length":f"{665 :.1f}K","pt_length":f"{558 :.1f}K"},
    "minicpm":{"data":minicpm_baseline, "ft_length":f"{665 :.1f}K","pt_length":f"{558 :.1f}K"},
    "minicpm_aug":{"data":minicpm_control, "ft_length":f"{665 :.1f}K","pt_length":f"{558 :.1f}K"},
}
method_dict = qwen2vl_method_dict
method_list = list(method_dict.keys())

# %%
def get_results_to_list(method_list,method_dict,metric_list,metric_dict):
    res = {}
    for method in method_list:
        data = method_dict[method]["data"]
        method_res = []
        for metric in metric_list:
            metric_avg_acc = []
            for metric_idx,metric_item in enumerate(metric_dict[metric]):
                if alias_dict.get(metric,None) != None:
                    alias = alias_dict[metric]
                    metric_big = data.get(metric,{}).get(metric_item,-1)
                    metric_alias = data.get(alias,{}).get(metric_item,-1)
                    metric_res = max(metric_big,metric_alias)
                else:
                    if metric == "mmstar" and data.get(metric,-1) != -1:
                        mmstar_avg_list = [data[metric].get(mms_item,-1) for mms_item in mmstar_basic_list]
                        mmstar_avg = sum(mmstar_avg_list)/len(mmstar_avg_list)
                        metric_res = data[metric].get(metric_item,mmstar_avg)
                    else:
                        metric_res = data.get(metric,{}).get(metric_item,-1)
                if metric not in ["mme","mmbench_cn_dev","mmbench_en_dev","llava_bench_coco","llava_in_the_wild","mmec"] and metric_res != -1 and metric_res != -2:
                    metric_res *= 100
                metric_avg_acc.append(metric_res)
                if method == "baseline" and metric_idx == 0 and llava_paper_dict.get(metric,-1) != -1:
                    metric_res = llava_paper_dict[metric]
                method_res.append(metric_res)
        res[method] = method_res
    return res

def form_latex_str(res,method_dict):
    res_str = ""
    method_list = list(res.keys())
    res_dict = {method:f"{method} & {method_dict[method]['ft_length']} " for method in method_list}
    avg_dict = {method:[] for method in method_list}
    for i in range(len(res[method_list[0]])):
        compare_list = sorted([res[method][i] for method in method_list])
        for method in method_list:
            if res[method][i] == compare_list[-1]:
                res_dict[method] += f"& \\textbf{{{res[method][i]:.1f}}}"
            elif res[method][i] == compare_list[-2]:
                res_dict[method] += f"& \\underline{{{res[method][i]:.1f}}}"
            else:
                res_dict[method] += f"& {res[method][i]:.1f}"
            avg_dict[method].append(res[method][i])
    avg_dict = {method:f" & {sum(avg_dict[method])/len(avg_dict[method]):.1f}" for method in method_list}
    for method in method_list:
        res_str += res_dict[method] + avg_dict[method] + "\\\\ \n"
    return res_str
        
def form_excel_str(res,method_dict):
    res_str = ""
    method_list = list(res.keys())
    res_dict = {method:f"{method}\t{method_dict[method]['pt_length']}\t{method_dict[method]['ft_length']}" for method in method_list}
    avg_dict = {method:[] for method in method_list}
    for i in range(len(res[method_list[0]])):
        compare_list = sorted([res[method][i] for method in method_list])
        for method in method_list:
            
            res_dict[method] += f"\t{res[method][i]:.1f}"
            avg_dict[method].append(res[method][i])
    avg_dict = {method:f"\t{sum(avg_dict[method])/len(avg_dict[method]):.1f}" for method in method_list}
    for method in method_list:
        res_str += res_dict[method] + avg_dict[method] + "\n"
    return res_str

# %%
res = get_results_to_list(method_list,method_dict,metric1_list,metric_dict)
res_str = form_latex_str(res,method_dict)
print(res_str)
# Out:
# qwen2vl & 665.0K & 79.2& \textbf{77.7}& \underline{54.2}& \underline{63.9}& 61.4& 80.9& 81.7& \textbf{-1.0}& \textbf{-1.0}& \underline{79.6}& 87.0& \underline{68.8}& \underline{43.6} & 59.7\\
# qwen2vl_aug & 665.0K & 79.7& \underline{76.6}& 52.5& \textbf{64.6}& 59.3& 79.6& 81.1& \textbf{-1.0}& \textbf{-1.0}& \textbf{79.8}& \underline{87.9}& \textbf{69.6}& \textbf{44.7} & 59.5\\
# minicpm & 665.0K & \underline{79.8}& 71.9& 49.9& 61.2& \textbf{66.0}& \textbf{88.7}& \textbf{93.4}& \textbf{-1.0}& \textbf{-1.0}& 61.4& 87.2& 67.3& 41.8 & 59.0\\
# minicpm_aug & 665.0K & \textbf{79.9}& 71.6& \textbf{55.8}& 62.6& \underline{62.5}& \underline{87.7}& \underline{92.6}& \textbf{-1.0}& \textbf{-1.0}& 64.8& \textbf{88.1}& 67.3& 42.0 & 59.4\\

# %%
res = get_results_to_list(method_list,method_dict,metric_excel_list,metric_dict)
res_str = form_excel_str(res,method_dict)
print(res_str)
# Out:
# qwen2vl	558.0K	665.0K	79.2	77.7	54.2	63.9	61.4	80.9	81.7	66.9	52.6	59.4	43.9	79.6	87.0	68.8	43.6	77.8	76.1	51.8	65.7	-1.0	565.4	72.7	51.9	73.3	84.8
# qwen2vl_aug	558.0K	665.0K	79.7	76.6	52.5	64.6	59.3	79.6	81.1	51.6	41.9	47.1	36.9	79.8	87.9	69.6	44.7	77.4	73.9	52.2	66.0	-1.0	571.8	71.6	47.0	75.2	82.8
# minicpm	558.0K	665.0K	79.8	71.9	49.9	61.2	66.0	88.7	93.4	38.0	29.9	37.9	29.1	61.4	87.2	67.3	41.8	80.7	78.5	54.8	64.9	-1.0	530.4	71.2	48.3	72.8	79.3
# minicpm_aug	558.0K	665.0K	79.9	71.6	55.8	62.6	62.5	87.7	92.6	24.6	20.9	25.8	21.1	64.8	88.1	67.3	42.0	80.1	77.7	51.8	65.4	-1.0	506.1	71.2	46.8	73.5	76.6

# %%
res = get_results_to_list(method_list,method_dict,detailed_main_res_list,metric_dict)
res_str = form_latex_str(res,method_dict)
print(res_str)
# Out:
# baseline & 665.0K & 53.4& 48.7& 47.3& 33.3& 1509.9& 66.8& 36.4& 46.0& 62.0& 64.3& 76.6 & 185.9\\
# random & 581.0K & 55.9& 47.3& 47.3& 34.9& 1472.4& 68.8& \textbf{36.9}& 46.4& 62.3& 65.5& 77.0 & 183.2\\
# perplexity & 581.0K & 52.2& 47.4& 47.1& 33.7& 1484.4& 68.8& 36.3& 45.8& 62.3& 63.7& 76.7 & 183.5\\
# randomaug & 665.0K & 48.9& 47.4& 48.3& 34.8& 1493.2& \textbf{70.6}& 36.4& 46.4& 62.5& 64.4& 77.1 & 184.6\\
# simpleaug & 665.0K & 56.0& \textbf{57.7}& -1.0& -1.0& 1469.4& 69.3& 35.8& 46.2& \textbf{63.0}& -1.0& 76.8 & 170.1\\
# balance & 581.0K & 55.3& 57.2& 46.8& 33.8& 1470.6& 69.5& 34.8& 46.0& 62.8& 65.5& 76.9 & 183.5\\
# ours & 665.0K & 55.1& \underline{57.4}& \underline{49.6}& \textbf{35.5}& \underline{1511.3}& \underline{70.2}& 36.3& 46.5& 62.9& 65.0& 76.9 & 187.9\\
# ours_control & 665.0K & 51.8& 47.6& 48.8& \underline{35.3}& \textbf{1512.8}& 69.1& 36.2& 46.7& 62.4& 64.7& 76.8 & 186.6\\
# ...
